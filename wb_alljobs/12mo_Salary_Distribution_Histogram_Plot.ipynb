# %% [markdown]
# ## All  Jobs Monthly Salary Statistics

# %%
import psycopg2
import pandas as pd
import plotly
import chart_studio.plotly as py
import plotly.graph_objs as go

from nbstyler import DATA_STYLE as DS

plotly.offline.init_notebook_mode(connected=True)

# %matplotlib notebook
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Objectives

# %% [markdown]
# ### Data Preparation

# %%
# %%time

conn = psycopg2.connect("dbname=jobsbg")

#   the full set of results will overload plotly, select only last three months.
offers_df = pd.read_sql_query("SELECT * FROM mv_jobs_with_salary WHERE subm_date > now() - interval '12 months'", conn, index_col = 'subm_date')

offers_df = offers_df[1:-1]

offers_df.index = pd.to_datetime(offers_df.index)
len(offers_df)
# Out:
# CPU times: user 1.35 s, sys: 34.8 ms, total: 1.38 s
# Wall time: 1.53 s
# 136929

# %%
hist_data = list(offers_df['norm_salary'])

# %%
hist_data[-6:-1]
# Out:
# [675.0, 900.0, 1050.0, 712.5, 1100.0]

# %%
group_labels = ['distplot']

# %%
data = go.Histogram(
    x=hist_data,
    histnorm='percent',
    xbins=dict(
        start=200,
        end=16000,
        size=150
    ),
    marker=dict(
        color=DS['colorramp']['acc1'][2],
        line=dict(
            width=1,
            color=DS['colors']['acc1']
        ),
    ),
)

# %%
layout = go.Layout(
    paper_bgcolor=DS['colors']['bg1'],            
    plot_bgcolor=DS['colors']['bg1'],
    title='Salary Distribution Histogram (last 12 months)',
    titlefont=DS['chart_fonts']['title'],
    font=DS['chart_fonts']['text'],
    autosize=True,
    showlegend=False,
    hidesources=True,
    xaxis = dict(
        title='Salary (BGN)',
        fixedrange=False,
        range=[0, 6000],
        hoverformat='0f',
        tickformat=',',
        ticks='outside',
        tickmode='auto',
        gridcolor=DS['colors']['bg3'],
        zerolinecolor=DS['colors']['bg3'],
    ),
    yaxis = dict(
        title='% Offers',
        type='linear',
        fixedrange=False,
        range=[0, 20],
        gridcolor=DS['colors']['bg3'],
        zerolinecolor=DS['colors']['bg3'],
        tickformat='',
        hoverformat='.2f',
        ticks='outside',
        tickwidth=1,
    ),
)

# %%
fig = go.Figure(data=data, layout=layout)

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="b3d24276-085c-4e81-9cbb-216e715bf481" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b3d24276-085c-4e81-9cbb-216e715bf481")) {
#                     Plotly.newPlot(
#                         'b3d24276-085c-4e81-9cbb-216e715bf481',
#                         [{"histnorm": "percent", "marker": {"color": "#e6c4a9", "line": {"color": "#bf4d28", "width": 1}}, "type": "histogram", "x": [1312.5, 875.0, 1100.0, 1200.0, 900.0, 1200.0, 1087.5, 850.0, 562.5, 900.0, 1200.0, 1200.0, 975.0, 975.0, 1000.0, 1200.0, 1100.0, 787.5, 900.0, 825.0, 750.0, 1550.0, 1500.0, 6500.0, 862.5, 637.5, 1500.0, 1087.
# %%
from IPython.core.display import HTML
with open('../resources/styles/datum.css', 'r') as f:
    style = f.read()
HTML(style)
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Fira+Mono|Fira+Sans|Fira+Sans+Condensed|Fira+Sans+Extra+Condensed');
# @import url('https://fonts.googleapis.com/css?family=Merriweather|Merriweather+Sans');
#
# .nbviewer {
#     background-color: #E5E1D8;
# }
#
# #notebook {
#     background-color: #E5E1D8;
# }
#
# #notebook-container {
#     background-color: #FFFAF0;
#     max-width: 1100px;
#     padding: 50px;
#     border-radius: 4px;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     -moz-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
# }
#
# /* Jupyter Notebook Header Styling */
# body > #header {
#     background-color:#fafafa;
# }
#
# #header #menubar #menus {
#     background-color:#fefefe;
# }
#
# /* Headings */
# .text_cell_render h1 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 900;
#     text-align: center;
#     font-size: 2.5em;
#     padding: 40px 0 12px 0;
#     text-shadow: 0 2px #FFFAF0, 0 3px #8c8b8b;
# }
#
# .text_cell_render h2 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 600;
#     font-size: 2.2em;
#     text-indent: 22px;
#     padding: 40px 0 6px 0;
#     margin-bottom: 24px;
#     border-bottom: 1px solid #655B4F;
# }
#
# .text_cell_render h3 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 300;
#     padding: 6px 0 0 0;
#     font-size: 1.6em;
# }
#
# .text_cell_render h4 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 100;
#     font-size: 1.2em;
# }
#
# /* Use for subtitles and other non-headings */
# div.rendered_html > h5 {
#     font-family: 'Merriweather', serif;
#     line-height: 1.5em;
#     color: #655B4F;
#     font-weight: 200;
#     font-style: normal important!;
#     text-indent: 22px;
#     text-align: center;
#     margin-top: 0.5em;
#     padding: 6px 0 6px 0;
#     border-bottom: 1px solid #655B4F;
#     border-top: 1px solid #655B4F;
# }
#
# /* Use for image and chart captions */
# div.rendered_html > h6 {
#     font-family: 'Merriweather Sans', sans-serif;
#     font-size: 0.9em;
#     line-height: 1.5em;
#     color: #cac8c9;
#     font-weight: normal;
#     max-width: 525px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div#notebook-container p {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 1.2em;
#     line-height: 1.3em;
#     color: #655B4F;
# }
#
# /* Plotly Exported Charts Styling */
# .js-plotly-plot .plotly,
# .js-plotly-plot .plotly div {
#     direction: ltr;
#     font-family: "Fira Sans Extra Condensed", verdana, arial, sans-serif;
# }
#
# /* Lists */
# ol, ul {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     line-height: 1.3em;
#     color: #655B4F;
# }
#
# div.input_prompt {
#     color: #aad0bc;
#     font-size: 0.7em;
# }
#
# div.output_prompt {
#     color: #aad0bc;
#     font-size: 0.7em;
# }
#
# div.prompt {
#     min-width: 2ex;
# }
#
# div.output_subarea {
#     min-width: 425px;
#     max-width: calc(100% - 1ex);
#     padding: 0;
# }
#
# div.text_cell code {
#     padding: 2px;
#     background-color: #E5E1D8;
#     color: #483F3A;
#     font-family: 'Fira Mono', monospace;
#     font-size: 0.9em;
# }
#
# div.input_area {
#     background-color: #FFFAF0;
#     border: 1px solid #E5E1D8;
#     background: repeating-linear-gradient(135deg, #FFFAF0, #FFFAF0 5px, #F7F7ED 5px, #F7F7ED 10px);
# }
#
# div.cell.rendered.selected {
#     background: #F7F7ED;
#     border: 1px solid #293C34;
# }
#
# div.output_area img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.rendered_html pre, code {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 16px;
#     font-weight: 400;
#     color: #40362F;
#     background-color: #E5E1D8;
# }
#
# div.output_text pre {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 13px;
#     font-weight: 300;
#     color: #40362F;
# }
#
#
# pre, textarea {
#     overflow: hidden;
# }
#
# div.text_cell_render img {
#     max-height: 550px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.output output_scroll {
#     overflow-x: auto;
#     overflow-y: scroll;
#     max-height: 2000px;
# }
#
# div.rendered_html hr {
#     border: 0;
#     height: 1px;
#     background-color: #655B4F;
# }
#
# div.rendered_html pre, code {
#     color: #40362F;
#     background-color: #FFFAF0;
# }
#
# /* Links */
# a.link--embedview {
#     display: none;
# }
#
# a:link {
#     color: #293C34;
# }
#
# a:visited {
#     color: #293C34;
# }
#
# a:hover {
#     color: #557C6C;
# }
#
# a:focus {
#     color:#557C6C;
# }
#
# a:active {
#     font-weight: bold;
#     color:#80BCA3;
# }
#
# .rendered_html :link {
#     text-decoration: underline;
# }
#
# /* Colors for code highlighting */
# .CodeMirror pre {
#     font-family: 'Fira Mono', monospace;
#     font-size: 0.9em;
#     font-weight: 600;
# }
#
# .CodeMirror-code span.cm-keyword,
# .highlight .k,
# .highlight .ow {
#     color: #5F362E;
# }
#
# .CodeMirror-code span.cm-variable,
# .highlight .na {
#     color: #655B4F;
# }
#
# .CodeMirror-code span.cm-property {
#     color: #655B4F;
# }
#
# .CodeMirror-code span.cm-def {
#     color: #293C34;
# }
#
# .CodeMirror-code span.cm-operator {
#     color: #655B4F;
# }
#
# .CodeMirror-code span.cm-string,
# .highlight .s {
#     color: #0B7761;
# }
#
# .CodeMirror-code span.cm-number,
# .highlight .mb, .highlight .mf, .highlight .mh, .highlight .mi, .highlight .mo {
#     color: #265BCA;
# }
#
# .CodeMirror-code span.cm-comment,
# .highlight .c1, .highlight .cs {
#     color: #75AC95;
# }
#
# .CodeMirror-code span.cm-builtin,
# .highlight .nb {
#     color: #5F362E;
# }
#
# /* Code with no class applied (brackets mostly) */
# .CodeMirror-line > span {
#     color: #72614B;
# }
#
# /* Table styles */
# table {
#     border: 1px solid #BF4D28;
# }
#
#
# .rendered_html table th {
#     color: #40362F;
#     text-align: left;
#     background-color: #f2e6ce;
# }
#
# .rendered_html td {
#     color: #40362F;
#     text-align: left;
# }
#
# .rendered_html table tr:nth-child(odd) {
#     background-color: #F7F7ED;
# }
#
# .rendered_html table tr:nth-child(even) {
#     background-color: #FFFAF0;
# }
#
# iframe {
#     border-width: 0;
# }
#
# @media only screen and (max-width: 600px) {
#     #notebook-container {
#         background-color: #FFFAF0;
#         padding: 15px;
#         border-radius: 4px;
#         -webkit-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#         -moz-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#         box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     }
#
#     .text_cell_render h1,
#     .text_cell_render h2 {
#         text-indent: 0;
#         text-align: left;
#         padding: 40px 22px 12px 22px;
#     }
# }
#
# </style>
