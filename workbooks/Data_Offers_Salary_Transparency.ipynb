# %% [markdown]
# ## Data Offers Salary Transparency

# %%
import psycopg2
import pandas as pd
import matplotlib
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

from nbstyler import DATA_STYLE as DS

plotly.offline.init_notebook_mode(connected=True)

# %matplotlib notebook
# %matplotlib inline
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ### Objectives
#
# The main objective of this visualization is to illustrate the ratio of data related job offer ads that have a salary announced as a part of the total offer count.

# %% [markdown]
# ### Methodology
#
# A percent stacked area graph was chosen to illustrate the salary transparency ratio. In this type of chart the value of each group is normalized at each time stamp and presented as a percentage part of the whole, allowing the reader to compare the groups that compose the whole. In order to hide the noise from daily fluctuations the data has been aggregated in time period bins spanning one month.

# %% [markdown]
# ### Data Preparation
#
# First we need to fetch the data from the database. A predefined query will return the counts we need, but we need to drop the first and last week from the result since they contain partial data for the relevant periods. Finally, visually inspect a couple of lines to confirm that the data looks as expected.

# %%
conn = psycopg2.connect("dbname=jobsbg")
query = 'SELECT * FROM v_data_offers_salary_disclosure_counts_weekly'

data_df = pd.read_sql_query(query, conn, index_col='week_ts')
data_df = data_df[1:-1]  # first and last week are incomplete so we drop them.
data_df.index = pd.to_datetime(data_df.index)  # convert the DataFrame index to DatetimeIndex object
data_df.head(2)
# Out:
#             published_salary  unpublished_salary
# week_ts
# 2017-10-02                 5                  28
# 2017-10-09                 0                  15

# %%
publ_salary_ratio = data_df.apply(lambda row: row.published_salary / (row.published_salary + row.unpublished_salary) * 100, axis=1)
unpubl_salary_ratio = data_df.apply(lambda row: row.unpublished_salary / (row.published_salary + row.unpublished_salary) * 100, axis=1)

data_df = data_df.assign(publ_salary_ratio=publ_salary_ratio.values)
data_df = data_df.assign(unpubl_salary_ratio=unpubl_salary_ratio.values)
data_df.head(1)
# Out:
#             published_salary  unpublished_salary  publ_salary_ratio  \
# week_ts
# 2017-10-02                 5                  28          15.151515
#
#             unpubl_salary_ratio
# week_ts
# 2017-10-02            84.848485

# %% [markdown]
# ### Implementing the Chart in Plotly
#
# Constructing the area traces for both possible values. They represent the data for the Plotly plot. Drawing directly as a line shape.

# %%
trace_publ = go.Scatter(
    x=data_df.index,
    y=data_df.publ_salary_ratio,
    text=data_df.published_salary,
    hoverinfo='text', 
    mode='lines',
    line=dict(
        width=1.5, 
        color=DS['colors']['acc1'],
        shape='linear',
    ),
    fillcolor=DS['colorramp']['acc1'][2],
    stackgroup='one',
    name='Published Salary',
)

trace_unpubl = go.Scatter(
    x=data_df.index,
    y=data_df.unpubl_salary_ratio,
    text=data_df.unpublished_salary,
    hoverinfo='text', 
    mode='lines',
    line=dict(
        width=0, 
        color=DS['colorramp']['acc2'][4],
    ),
    stackgroup='one',
    name='Unpublished Salary'
)

data = [trace_publ, trace_unpubl]

# %% [markdown]
# Preparing the layout for the Plotly plot.

# %%
layout = go.Layout(
    paper_bgcolor=DS['colors']['bg1'],
    plot_bgcolor=DS['colors']['bg1'],
    title='Salary Transparency in Data Jobs',
    titlefont=DS['chart_fonts']['title'],
    font=DS['chart_fonts']['text'],
    legend=dict(orientation='h'),
    modebar=dict(orientation='h'),
    autosize=True,
    showlegend=True,
    hidesources=True,
    dragmode='zoom',
    hovermode='closest',
    hoverlabel=dict(
        bgcolor=DS['colors']['bg1']
    ),
    xaxis = dict(
        type='date', 
        fixedrange=True,
        hoverformat='Week %W, %Y',
        ticks='outside',
        tickmode='auto',
        zerolinecolor=DS['colors']['fg2'],
        ), 
    yaxis = dict(
        title='Total submissions distribution',
        fixedrange=True,
        ticks='outside',
        tickwidth=1,
        gridcolor=DS['colors']['bg3'],
        type='linear',
        range=[0,100],
        ticksuffix='%',
    ),
)

# %%
fig = go.Figure(data = data, layout = layout)
plotly.offline.iplot(fig, filename = 'data_jobs_salary_transparency')
# Uncomment the line below to export an HTML version of the chart.
# plotly.offline.plot(fig, filename='data_jobs_salary_transparency.html', show_link=False)
# Out:
# <div id="602412ee-4e9c-4fc8-80dc-55ca7b84042f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("602412ee-4e9c-4fc8-80dc-55ca7b84042f", [{"fillcolor": "#e6c4a9", "hoverinfo": "text", "line": {"color": "#bf4d28", "shape": "linear", "width": 1.5}, "mode": "lines", "name": "Published Salary", "stackgroup": "one", "text": [5.0, 0.0, 1.0, 6.0, 1.0, 0.0, 1.0, 1.0, 1.0, 6.0, 1.0, 0.0, 0.0, 1.0, 2.0, 1.0, 1.0, 1.0, 0.0, 3.0, 3.0, 2.0, 0.0, 4.0, 3.0, 5.0, 2.0, 4.0, 1.0, 6.0, 3.0, 3.0, 1.0, 1.0, 3.0, 3.0, 3.0, 2.0, 4.0, 4.0, 4.0, 3.0, 6.0, 6.0, 3.0, 6.0, 4.0, 4.0, 5.0, 5.0, 1.0, 2.0, 6.0, 3.0, 6.0, 7.0, 1.0, 3.0, 3.0, 4.0, 3.0, 5.0, 5.0, 1.0, 2.0, 3.0, 6.0, 4.0, 3.0, 4.0, 5.0, 7.0, 3.0, 4.0, 4.0, 4.0, 2.0, 2.0, 4.0, 4.0, 8.0, 3.0, 4.0, 3.0, 9.0], "x": ["2017-10-01 21:00:00", "2017-10-08 21:00:00", "2017-10-15 21:00:00", "2017-10-22 21:00:00", "2017-10-29 22:00:00", "2017-11-05 22:00:00", "2017-11-12 22:00:00", "2017-11-19 22:00:00", "2017-11-26 22:00:00", "2017-12-03 22:00:00", "2017-12-10 22:00:00", "2017-12-17 22:00:00", "2017-12-24 22:00:00", "2017-12-31 22:00:00", "2018-01-07 22:00:00", "2018-01-14 22:00:00", "2018-01-21 22:00:00", "2018-01-28 22:00:00", "2018-02-04 22:00:00", "2018-02-11 22:00:00", "2018-02-18 22:00:00", "2018-02-25 22:00:00", "2018-03-04 22:00:00", "2018-03-11 22:00:00", "2018-03-18 22:00:00", "2018-03-25 21:00:00", "2018-04-01 21:00:00", "2018-04-08 21:00:00", "2018-04-15 21:00:00", "2018-04-22 21:00:00", "2018-04-29 21:00:00", "2018-05-06 21:00:00", "2018-05-13 21:00:00", "2018-05-20 21:00:00", "2018-05-27 21:00:00", "2018-06-03 21:00:00", "2018-06-10 21:00:00", "2018-06-17 21:00:00", "2018-06-24 21:00:00", "2018-07-01 21:00:00", "2018-07-08 21:00:00", "2018-07-15 21:00:00", "2018-07-22 21:00:00", "2018-07-29 21:00:00", "2018-08-05 21:00:00", "2018-08-12 21:00:00", "2018-08-19 21:00:00", "2018-08-26 21:00:00", "2018-09-02 21:00:00", "2018-09-09 21:00:00", "2018-09-16 21:00:00", "2018-09-23 21:00:00", "2018-09-30 21:00:00", "2018-10-07 21:00:00", "2018-10-14 21:00:00", "2018-10-21 21:00:00", "2018-10-28 22:00:00", "2018-11-04 22:00:00", "2018-11-11 22:00:00", "2018-11-18 22:00:00", "2018-11-25 22:00:00", "2018-12-02 22:00:00", "2018-12-09 22:00:00", "2018-12-16 22:00:00", "2018-12-23 22:00:00", "2018-12-30 22:00:00", "2019-01-06 22:00:00", "2019-01-13 22:00:00", "2019-01-20 22:00:00", "2019-01-27 22:00:00", "2019-02-03 22:00:00", "2019-02-10 22:00:00", "2019-02-17 22:00:00", "2019-02-24 22:00:00", "2019-03-03 22:00:00", "2019-03-10 22:00:00", "2019-03-17 22:00:00", "2019-03-24 22:00:00", "2019-03-31 21:00:00", "2019-04-07 21:00:00", "2019-04-14 21:00:00", "2019-04-21 21:00:00", "2019-04-28 21:00:00", "2019-05-05 21:00:00", "2019-05-12 21:00:00"], "y": [15.151515151515152, 0.0, 3.8461538461538463, 22.22222222222222, 6.25, 0.0, 5.0, 4.761904761904762, 3.3333333333333335, 20.689655172413794, 5.263157894736842, 0.0, 0.0, 5.263157894736842, 5.88235294117647, 3.7037037037037033, 5.0, 4.545454545454546, 0.0, 9.375, 10.344827586206897, 9.523809523809524, 0.0, 13.333333333333334, 16.666666666666664, 16.129032258064516, 9.523809523809524, 12.5, 3.225806451612903, 18.181818181818183, 9.090909090909092, 8.571428571428571, 2.272727272727273, 3.225806451612903, 8.333333333333332, 9.375, 7.317073170731707, 7.142857142857142, 11.428571428571429, 16.666666666666664, 10.0, 9.67741935483871, 14.285714285714285, 18.75, 9.090909090909092, 18.75, 9.523809523809524, 13.333333333333334, 22.727272727272727, 11.363636363636363, 3.0303030303030303, 5.714285714285714, 15.789473684210526, 8.571428571428571, 16.216216216216218, 17.5, 2.380952380952381, 7.5, 8.333333333333332, 13.333333333333334, 6.666666666666667, 17.24137931034483, 14.705882352941178, 2.7027027027027026, 25.0, 8.108108108108109, 11.538461538461538, 10.81081081081081, 9.090909090909092, 10.52 ...
# 'file:///data/WORKSPACE/jpynb_Employment_Trends_Bulgaria/workbooks/data_jobs_salary_transparency.html'

# %%
from IPython.core.display import HTML
with open('../resources/styles/datum.css', 'r') as f:
    style = f.read()
HTML(style)
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Fira+Mono|Fira+Sans|Fira+Sans+Condensed|Fira+Sans+Extra+Condensed');
# @import url('https://fonts.googleapis.com/css?family=Merriweather|Merriweather+Sans');
#
# .nbviewer {
#     background-color: #E5E1D8;
# }
#
# #notebook {
#     background-color: #E5E1D8;
# }
#
# #notebook-container {
#     background-color: #FFFAF0;
#     max-width: 1200px;
#     border-radius: 4px;
#     padding: 60px 40px 40px 40px;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     -moz-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
# }
#
# /* Jupyter Notebook Header Styling */
# body > #header {
#     background-color:#fafafa;
# }
#
# #header #menubar #menus {
#     background-color:#fefefe;
# }
#
# /* Headings */
# .text_cell_render h1 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 900;
#     text-align: center;
#     font-size: 3.2em;
#     text-shadow: 0 2px #FFFAF0, 0 3px #8c8b8b;
#     padding: 40px 0 12px 0;
# }
#
# .text_cell_render h2 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 600;
#     font-size: 2.4em;
#     text-indent: 22px;
#     padding: 40px 0 5px 0;
#     margin-bottom: 24px;
#     border-bottom: 1px solid #655643;
# }
#
# .text_cell_render h3 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 100;
#     font-size: 1.8em;
#     padding: 6px 0 0 0;
# }
#
# .text_cell_render h4 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 100;
#     font-size: 1.3em;
# }
#
# /* Use for subtitles and other non-headings */
# div.rendered_html > h5 {
#     font-family: 'Merriweather', serif;
#     line-height: 1.5em;
#     color: #655643;
#     font-weight: 200;
#     font-style: normal important!;
#     text-indent: 22px;
#     text-align: center;
#     margin-top: 0.5em;
#     padding: 6px 0 6px 0;
#     border-bottom: 1px solid #655643;
#     border-top: 1px solid #655643;
# }
#
# /* Use for image and chart captions */
# div.rendered_html > h6 {
#     font-family: 'Merriweather Sans', sans-serif;
#     font-size: 0.9em;
#     line-height: 1.5em;
#     color: #cac8c9;
#     font-weight: normal;
#     max-width: 525px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div#notebook-container p {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 1.2em;
#     line-height: 1.3em;
#     color: #655643;
# }
#
# /* Plotly Exported Charts Styling */
# .js-plotly-plot .plotly,
# .js-plotly-plot .plotly div {
#     direction: ltr;
#     font-family: "Fira Sans Extra Condensed", verdana, arial, sans-serif;
# }
#
#
# /* Lists */
# ol, ul {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     line-height: 1.3em;
#     color: #655643;
# }
#
# div.input_prompt {
#     color: #aad0bc;
#     font-size: 0.7em;
# }
#
# div.output_prompt {
#     color: #aad0bc;
#     font-size: 0.7em;
# }
#
# div.output_subarea {
#     padding: 0;
# }
#
# div.text_cell code {
#     padding: 2px;
#     background-color: #E5E1D8;
#     color: #40362F;
#     font-family: 'Fira Mono', monospace;
#     font-size: 0.9em;
# }
#
# div.input_area {
#     background-color: #FFFAF0;
#     border: 1px solid #E5E1D8;
#     background: repeating-linear-gradient(135deg, #FFFAF0, #FFFAF0 5px, #F7F7ED 5px, #F7F7ED 10px);
# }
#
# div.cell.rendered.selected {
#     background: #F7F7ED;
#     border: 1px solid #38614F;
# }
#
# div.output_area img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.rendered_html pre, code {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 16px;
#     font-weight: 400;
#     color: #40362F;
#     background-color: #E5E1D8;
# }
#
# div.output_text pre {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 13px;
#     font-weight: 300;
#     color: #40362F;
# }
#
# pre, textarea {
#     overflow: hidden;
# }
#
# div.text_cell_render img {
#     max-height: 550px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.output output_scroll {
#     overflow-x: auto;
#     overflow-y: scroll;
#     max-height: 2000px;
# }
#
# div.rendered_html hr {
#     border: 0;
#     height: 1px;
#     background-color: #655643;
# }
#
# div.rendered_html pre, code {
#     color: #40362F;
#     background-color: #FFFAF0;
# }
#
# /* Links */
# a.link--embedview {
#     display: none;
# }
#
# a:link {
#     color: #293C34;
# }
#
# a:visited {
#     color: #293C34;
# }
#
# a:hover {
#     color: #557C6C;
# }
#
# a:focus {
#     color:#557C6C;
# }
#
# a:active {
#     font-weight: bold;
#     color:#80BCA3;
# }
#
# .rendered_html :link {
#     text-decoration: underline;
# }
#
# /* Colors for code highlighting */
# .CodeMirror pre {
#     font-family: 'Fira Mono', monospace;
#     font-size: 0.9em;
#     font-weight: 600;
#     letter-spacing: -2px;
# }
#
# .CodeMirror-code span.cm-keyword,
# .highlight .k,
# .highlight .ow {
#     color: #5F362E;
# }
#
# .CodeMirror-code span.cm-variable,
# .highlight .na {
#     color: #72614B;
# }
#
# .CodeMirror-code span.cm-property {
#     color: #72614B;
# }
#
# .CodeMirror-code span.cm-def {
#     color: #B64F4E;
# }
#
# .CodeMirror-code span.cm-operator {
#     color: #72614B;
# }
#
# .CodeMirror-code span.cm-string,
# .highlight .s {
#     color: #0B7761;
# }
#
# .CodeMirror-code span.cm-number,
# .highlight .mb, .highlight .mf, .highlight .mh, .highlight .mi, .highlight .mo {
#     color: #2764E6;
# }
#
# .CodeMirror-code span.cm-comment,
# .highlight .c1, .highlight .cs {
#     color: #75AC95;
# }
#
# .CodeMirror-code span.cm-builtin,
# .highlight .nb {
#     color: #5F362E;
# }
#
# /* Code with no class applied (brackets mostly) */
# .CodeMirror-line > span {
#     color: #72614B;
# }
#
# /* Table styles */
# table {
#     border: 1px solid #BF4D28;
# }
#
# .rendered_html table {
#     float: middle;
#     border-collapse: collapse;
# }
#
# .rendered_html table th {
#     color: #40362F;
#     text-align: left;
#     background-color: #f2e6ce;
# }
#
# .rendered_html td {
#     color: #40362F;
#     text-align: left;
# }
#
# .rendered_html table tr:nth-child(odd) {
#     background-color: #F7F7ED;
# }
#
# .rendered_html table tr:nth-child(even) {
#     background-color: #FFFAF0;
# }
#
# .rendered_html table tr:hover {
#     background-color: #BF4D28;
# }
#
# iframe {
#     border-width: 0;
# }
# </style>
