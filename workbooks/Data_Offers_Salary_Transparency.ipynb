# %% [markdown]
# ## Data Offers Salary Transparency

# %%
import psycopg2
import pandas as pd
import matplotlib
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

from nbstyler import DATA_STYLE as DS

plotly.offline.init_notebook_mode(connected=True)

# %matplotlib notebook
# %matplotlib inline
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ### Objectives
#
# The main objective of this visualization is to illustrate the ratio of data related job offer ads that have a salary announced as a part of the total offer count.

# %% [markdown]
# ### Methodology
#
# A percent stacked area graph was chosen to illustrate the salary transparency ratio. In this type of chart the value of each group is normalized at each time stamp and presented as a percentage part of the whole, allowing the reader to compare the groups that compose the whole. In order to hide the noise from daily fluctuations the data has been aggregated in time period bins spanning one month.

# %% [markdown]
# ### Data Preparation
#
# First we need to fetch the data from the database. A predefined query will return the counts we need, but we need to drop the first and last week from the result since they contain partial data for the relevant periods. Finally, visually inspect a couple of lines to confirm that the data looks as expected.

# %%
conn = psycopg2.connect("dbname=jobsbg")
query_data = 'SELECT * FROM v_data_offers_salary_disclosure_counts_weekly'
query_all = 'SELECT * FROM v_salary_disclosure_counts_weekly'

# Data jobs
data_df = pd.read_sql_query(query_data, conn, index_col='week_ts')
data_df = data_df[1:-1]  # first and last week are incomplete so we drop them.
data_df.index = pd.to_datetime(data_df.index)  # convert the DataFrame index to DatetimeIndex object
data_df.head(2)

# All jobs
all_df = pd.read_sql_query(query_all, conn, index_col='week_ts')
all_df = all_df[1:-1]  # first and last week are incomplete so we drop them.
all_df.index = pd.to_datetime(all_df.index)  # convert the DataFrame index to DatetimeIndex object
all_df.head(2)
# Out:
#             published_salary  unpublished_salary
# week_ts
# 2017-10-02              2265                8016
# 2017-10-09              2179                7322

# %%
# Data jobs
data_publ_salary_ratio = data_df.apply(
    lambda row: row.published_salary / (row.published_salary + row.unpublished_salary) * 100, axis=1)
data_unpubl_salary_ratio = data_df.apply(
    lambda row: row.unpublished_salary / (row.published_salary + row.unpublished_salary) * 100, axis=1)

data_df = data_df.assign(data_publ_salary_ratio=data_publ_salary_ratio.values)
data_df = data_df.assign(data_unpubl_salary_ratio=data_unpubl_salary_ratio.values)

# All jobs
all_publ_salary_ratio = all_df.apply(
    lambda row: row.published_salary / (row.published_salary + row.unpublished_salary) * 100, axis=1)
all_unpubl_salary_ratio = all_df.apply(
    lambda row: row.unpublished_salary / (row.published_salary + row.unpublished_salary) * 100, axis=1)

all_df = all_df.assign(all_publ_salary_ratio=all_publ_salary_ratio.values)
all_df = all_df.assign(all_unpubl_salary_ratio=all_unpubl_salary_ratio.values)

# %% [markdown]
# ### Implementing the Chart in Plotly
#
# Constructing the area traces for both possible values. They represent the data for the Plotly plot. Drawing directly as a line shape.

# %%
trace_publ_data = go.Scatter(
    x=data_df.index,
    y=data_df.data_publ_salary_ratio,
    text=data_df.published_salary,
    hoverinfo='x+y+text', 
    mode='lines',
    line=dict(
        width=1.5, 
        color=DS['colors']['acc1'],
    ),
    fillcolor=DS['colorramp']['acc1'][2],
    stackgroup='one',
    name='Published Salary (Data Jobs)',
)

trace_publ_all = go.Scatter(
    x=all_df.index,
    y=all_df.all_publ_salary_ratio,
    text=all_df.published_salary,
    hoverinfo='x+y+text', 
    mode='lines',
    line=dict(
        width=1.5,
        color=DS['colors']['acc2'],
    ),
    fillcolor=DS['colorramp']['acc2'][2],
    stackgroup='two',
    name='Published Salary (All Jobs)'
)

data = [trace_publ_all, trace_publ_data]

# %% [markdown]
# Preparing the layout for the Plotly plot.

# %%
layout = go.Layout(
    paper_bgcolor=DS['colors']['bg1'],
    plot_bgcolor=DS['colors']['bg1'],
    title='Salary Transparency in Data Jobs',
    titlefont=DS['chart_fonts']['title'],
    font=DS['chart_fonts']['text'],
    legend=dict(orientation='h'),
    modebar=dict(orientation='h'),
    autosize=True,
    showlegend=True,
    hidesources=True,
    dragmode='zoom',
    hovermode='closest',
    hoverlabel=dict(
        bgcolor=DS['colors']['bg1']
    ),
    xaxis = dict(
        type='date', 
        fixedrange=True,
        hoverformat='Week %W, %Y',
        ticks='outside',
        tickmode='auto',
        zerolinecolor=DS['colors']['fg2'],
        ), 
    yaxis = dict(
        title='Total submissions distribution',
        fixedrange=True,
        ticks='outside',
        tickwidth=1,
        gridcolor=DS['colors']['bg3'],
        type='linear',
        range=[0,100],
        ticksuffix='%',
    ),
)

# %%
fig = go.Figure(data = data, layout = layout)

plotly.offline.iplot(fig, filename = 'data_jobs_salary_transparency')
# Out:
# <div id="d7453312-a770-468d-bb19-88f8edbc992c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d7453312-a770-468d-bb19-88f8edbc992c", [{"fillcolor": "#d4e5d6", "hoverinfo": "x+y+text", "line": {"color": "#75ac95", "width": 1.5}, "mode": "lines", "name": "Published Salary (All Jobs)", "stackgroup": "two", "text": [2265.0, 2179.0, 2304.0, 2376.0, 2072.0, 2206.0, 2054.0, 2163.0, 1901.0, 1798.0, 1670.0, 1263.0, 664.0, 2187.0, 2487.0, 2164.0, 1986.0, 2176.0, 2429.0, 2522.0, 2393.0, 1828.0, 2485.0, 3154.0, 2554.0, 2891.0, 2371.0, 3647.0, 3774.0, 3943.0, 3447.0, 3468.0, 4077.0, 3251.0, 3802.0, 3650.0, 3534.0, 3217.0, 2928.0, 2898.0, 2899.0, 2980.0, 2914.0, 2854.0, 2925.0, 2993.0, 3123.0, 3301.0, 2864.0, 3346.0, 3297.0, 2715.0, 2888.0, 2843.0, 2852.0, 2642.0, 2600.0, 2510.0, 2529.0, 2318.0, 2057.0, 2021.0, 1944.0, 1459.0, 732.0, 2298.0, 2937.0, 2552.0, 2299.0, 2329.0, 3033.0, 2854.0, 2832.0, 2824.0, 2932.0, 3542.0, 3492.0, 3526.0, 3508.0, 3857.0, 3803.0, 2851.0, 3125.0, 4082.0, 4360.0, 3404.0, 3911.0, 3834.0, 3876.0, 3845.0, 3143.0, 3199.0], "x": ["2017-10-01 21:00:00", "2017-10-08 21:00:00", "2017-10-15 21:00:00", "2017-10-22 21:00:00", "2017-10-29 22:00:00", "2017-11-05 22:00:00", "2017-11-12 22:00:00", "2017-11-19 22:00:00", "2017-11-26 22:00:00", "2017-12-03 22:00:00", "2017-12-10 22:00:00", "2017-12-17
# %%
from IPython.core.display import HTML
with open('../resources/styles/datum.css', 'r') as f:
    style = f.read()
HTML(style)
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Fira+Mono|Fira+Sans|Fira+Sans+Condensed|Fira+Sans+Extra+Condensed');
# @import url('https://fonts.googleapis.com/css?family=Merriweather|Merriweather+Sans');
#
# .nbviewer {
#     background-color: #E5E1D8;
# }
#
# #notebook {
#     background-color: #E5E1D8;
# }
#
# #notebook-container {
#     background-color: #FFFAF0;
#     max-width: 1100px;
#     padding: 50px;
#     border-radius: 4px;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     -moz-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
# }
#
# /* Jupyter Notebook Header Styling */
# body > #header {
#     background-color:#fafafa;
# }
#
# #header #menubar #menus {
#     background-color:#fefefe;
# }
#
# /* Headings */
# .text_cell_render h1 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 900;
#     text-align: center;
#     font-size: 2.5em;
#     padding: 40px 0 12px 0;
#     text-shadow: 0 2px #FFFAF0, 0 3px #8c8b8b;
# }
#
# .text_cell_render h2 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 600;
#     font-size: 2.2em;
#     text-indent: 22px;
#     padding: 40px 0 6px 0;
#     margin-bottom: 24px;
#     border-bottom: 1px solid #655B4F;
# }
#
# .text_cell_render h3 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 300;
#     padding: 6px 0 0 0;
#     font-size: 1.6em;
# }
#
# .text_cell_render h4 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 100;
#     font-size: 1.2em;
# }
#
# /* Use for subtitles and other non-headings */
# div.rendered_html > h5 {
#     font-family: 'Merriweather', serif;
#     line-height: 1.5em;
#     color: #655B4F;
#     font-weight: 200;
#     font-style: normal important!;
#     text-indent: 22px;
#     text-align: center;
#     margin-top: 0.5em;
#     padding: 6px 0 6px 0;
#     border-bottom: 1px solid #655B4F;
#     border-top: 1px solid #655B4F;
# }
#
# /* Use for image and chart captions */
# div.rendered_html > h6 {
#     font-family: 'Merriweather Sans', sans-serif;
#     font-size: 0.9em;
#     line-height: 1.5em;
#     color: #cac8c9;
#     font-weight: normal;
#     max-width: 525px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div#notebook-container p {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 1.2em;
#     line-height: 1.3em;
#     color: #655B4F;
# }
#
# /* Plotly Exported Charts Styling */
# .js-plotly-plot .plotly,
# .js-plotly-plot .plotly div {
#     direction: ltr;
#     font-family: "Fira Sans Extra Condensed", verdana, arial, sans-serif;
# }
#
# /* Lists */
# ol, ul {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     line-height: 1.3em;
#     color: #655B4F;
# }
#
# div.input_prompt {
#     color: #aad0bc;
#     font-size: 0.7em;
# }
#
# div.output_prompt {
#     color: #aad0bc;
#     font-size: 0.7em;
# }
#
# div.prompt {
#     min-width: 2ex;
# }
#
# div.output_subarea {
#     min-width: 425px;
#     max-width: calc(100% - 1ex);
#     padding: 0;
# }
#
# div.text_cell code {
#     padding: 2px;
#     background-color: #E5E1D8;
#     color: #483F3A;
#     font-family: 'Fira Mono', monospace;
#     font-size: 0.9em;
# }
#
# div.input_area {
#     background-color: #FFFAF0;
#     border: 1px solid #E5E1D8;
#     background: repeating-linear-gradient(135deg, #FFFAF0, #FFFAF0 5px, #F7F7ED 5px, #F7F7ED 10px);
# }
#
# div.cell.rendered.selected {
#     background: #F7F7ED;
#     border: 1px solid #293C34;
# }
#
# div.output_area img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.rendered_html pre, code {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 16px;
#     font-weight: 400;
#     color: #40362F;
#     background-color: #E5E1D8;
# }
#
# div.output_text pre {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 13px;
#     font-weight: 300;
#     color: #40362F;
# }
#
#
# pre, textarea {
#     overflow: hidden;
# }
#
# div.text_cell_render img {
#     max-height: 550px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.output output_scroll {
#     overflow-x: auto;
#     overflow-y: scroll;
#     max-height: 2000px;
# }
#
# div.rendered_html hr {
#     border: 0;
#     height: 1px;
#     background-color: #655B4F;
# }
#
# div.rendered_html pre, code {
#     color: #40362F;
#     background-color: #FFFAF0;
# }
#
# /* Links */
# a.link--embedview {
#     display: none;
# }
#
# a:link {
#     color: #293C34;
# }
#
# a:visited {
#     color: #293C34;
# }
#
# a:hover {
#     color: #557C6C;
# }
#
# a:focus {
#     color:#557C6C;
# }
#
# a:active {
#     font-weight: bold;
#     color:#80BCA3;
# }
#
# .rendered_html :link {
#     text-decoration: underline;
# }
#
# /* Colors for code highlighting */
# .CodeMirror pre {
#     font-family: 'Fira Mono', monospace;
#     font-size: 0.9em;
#     font-weight: 600;
#     letter-spacing: -2px;
# }
#
# .CodeMirror-code span.cm-keyword,
# .highlight .k,
# .highlight .ow {
#     color: #5F362E;
# }
#
# .CodeMirror-code span.cm-variable,
# .highlight .na {
#     color: #655B4F;
# }
#
# .CodeMirror-code span.cm-property {
#     color: #655B4F;
# }
#
# .CodeMirror-code span.cm-def {
#     color: #293C34;
# }
#
# .CodeMirror-code span.cm-operator {
#     color: #655B4F;
# }
#
# .CodeMirror-code span.cm-string,
# .highlight .s {
#     color: #0B7761;
# }
#
# .CodeMirror-code span.cm-number,
# .highlight .mb, .highlight .mf, .highlight .mh, .highlight .mi, .highlight .mo {
#     color: #265BCA;
# }
#
# .CodeMirror-code span.cm-comment,
# .highlight .c1, .highlight .cs {
#     color: #75AC95;
# }
#
# .CodeMirror-code span.cm-builtin,
# .highlight .nb {
#     color: #5F362E;
# }
#
# /* Code with no class applied (brackets mostly) */
# .CodeMirror-line > span {
#     color: #72614B;
# }
#
# /* Table styles */
# table {
#     border: 1px solid #BF4D28;
# }
#
#
# .rendered_html table th {
#     color: #40362F;
#     text-align: left;
#     background-color: #f2e6ce;
# }
#
# .rendered_html td {
#     color: #40362F;
#     text-align: left;
# }
#
# .rendered_html table tr:nth-child(odd) {
#     background-color: #F7F7ED;
# }
#
# .rendered_html table tr:nth-child(even) {
#     background-color: #FFFAF0;
# }
#
# iframe {
#     border-width: 0;
# }
#
# @media only screen and (max-width: 600px) {
#     #notebook-container {
#         background-color: #FFFAF0;
#         padding: 15px;
#         border-radius: 4px;
#         -webkit-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#         -moz-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#         box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     }
#
#     .text_cell_render h1,
#     .text_cell_render h2 {
#         text-indent: 0;
#         text-align: left;
#         padding: 40px 22px 12px 22px;
#     }
# }
#
# </style>
