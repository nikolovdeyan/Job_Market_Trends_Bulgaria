# %% [markdown]
# ## Programming Languages Demand
#
# ----------
# ### Introduction
#
# - Objectives:
#  - Provide graphs showing the number of offers listing the specific language in the offer title.
#  - Provide selectable levels of aggregation: week, month. Upon testing the weekly counts were determied to be too wildly variant, so either a running average has to be used or the monthly values.
#  - Provide a Jupyter Workbook Widget to switch between the aggregation levels.
#
# ### Methodology
#
# - To produce correct counts POSIX Regular Expressions matching was used.
# https://www.postgresql.org/docs/9.3/functions-matching.html

# %% [markdown]
# ### Prototyping
#
# Using `matplotlib` to prepare the necessary data and confirm it is suitable for plotting.

# %%
import datetime
import psycopg2
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import ipywidgets as widgets
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True) # run at the start of every ipython notebook to use plotly.offline

# %matplotlib notebook
# %matplotlib inline

from nbstyler import STYLE
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
conn = psycopg2.connect("dbname=jobsbg")
week_df = pd.read_sql_query('SELECT * FROM v_programming_lang_demand_weekly', conn, index_col='week_ts')
month_df = pd.read_sql_query('SELECT * FROM v_programming_lang_demand_monthly', conn, index_col='month_ts')

week_df = week_df[1:-1]
month_df = month_df[1:-1]

week_df.index = pd.to_datetime(week_df.index)
month_df.index = pd.to_datetime(month_df.index)

# %%
cols_to_plot = ['java_count', 'php_count', 'js_count', 'cplusplus_count', 'python_count', 'csharp_count']

week_df = week_df[cols_to_plot]
month_df = month_df[cols_to_plot]

# %%
cnt_month.plot(
    title='Monthly Demand for Selected Programming Languages',
    y=cols_to_plot,
    kind='line',
    grid=True,
    linewidth=2,
    figsize=(16,8)
)

# %% [markdown]
# ### Implementing the Chart in Plotly

# %%
traces = []
annotations = []
month_df.columns = ['Java', 'PHP', 'JavaScript', 'C++', 'Python', 'C#']
y_data = [list(month_df[lang].values) for lang in month_df.columns]

# %%
x_data = [list(month_df.index)]

# %%
for lang in month_df.columns:
    traces.append(go.Scatter(
        x = month_df.index,
        y = month_df[lang].values,
        mode = 'lines',
        line = dict(
            shape = 'linear',
        ),
        hoverinfo = 'y',
    ))

# %%
layout = go.Layout(
    width = 920,
    height = 600,
    paper_bgcolor = '#1c3b56',            
    plot_bgcolor = '#1c3b56',
    font = dict(
        color = STYLE['colors']['solid']['fg2'],
        family = STYLE['fonts']['default']['family'],
        size = STYLE['fonts']['default']['size'],
    ),
    title = 'Languages Appearance in Job Offer Titles',
    titlefont = dict(
        color = STYLE['colors']['solid']['fg2'],
        family = STYLE['fonts']['titlefont']['family'],
        size = STYLE['fonts']['titlefont']['size'],
    ),    
    xaxis = dict(
        showline = True,
        showgrid = False,
        showticklabels = True,
        linecolor = STYLE['colors']['solid']['acc4'],
        linewidth = 2,
    ),
    yaxis = dict(
        showgrid = True,
        zeroline = False,
        showline = False,
        showticklabels = False,
    ),
    autosize = False,
    margin = dict(
        autoexpand = False,
        l=100,
        r=20,
        t=110,
    ),
    showlegend = False
)

# %%
colors = [
    STYLE['colors']['solid']['acc1'], 
    STYLE['colors']['solid']['acc2'], 
    STYLE['colors']['solid']['acc3'],
    STYLE['colors']['solid']['acc4'],
    STYLE['colors']['solid']['acc5'],
    'red','maroon', 'purple']

for y_trace, label, color in zip(y_data, cnt_month.columns, colors):
    # Create labels for the left hand side
    annotations.append(dict(
        xref = 'paper',
        x = 0,
        y = y_trace[0],
        xanchor = 'right',
        yanchor = 'middle',
        text = label,
        font = dict(
            family = STYLE['fonts']['default']['family'],
            size = STYLE['fonts']['default']['size'],),
        showarrow = False),
    )

# %%
layout['annotations'] = annotations

fig = go.Figure(data = traces, layout = layout)

plotly.offline.iplot(fig, filename = 'programming_lang_demand.html')

# Uncomment the line below to export an HTML version of the chart.
# plotly.offline.plot(fig, filename = 'programming_lang_demand.html')
# Out:
# <div id="c14b9ec2-7092-4624-974b-6e759e3f647f" style="height: 600px; width: 920px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c14b9ec2-7092-4624-974b-6e759e3f647f", [{"hoverinfo": "y", "line": {"shape": "linear"}, "mode": "lines", "x": ["2017-09-30 21:00:00", "2017-10-31 22:00:00", "2017-11-30 22:00:00", "2017-12-31 22:00:00", "2018-01-31 22:00:00", "2018-02-28 22:00:00", "2018-03-31 21:00:00", "2018-04-30 21:00:00", "2018-05-31 21:00:00", "2018-06-30 21:00:00", "2018-07-31 21:00:00", "2018-08-31 21:00:00", "2018-09-30 21:00:00", "2018-10-31 22:00:00"], "y": [167, 180, 130, 173, 150, 153, 167, 164, 179, 184, 193, 182, 204, 210], "type": "scatter", "uid": "a613304d-e283-4a74-ab74-de4bcea47e90"}, {"hoverinfo": "y", "line": {"shape": "linear"}, "mode": "lines", "x": ["2017-09-30 21:00:00", "2017-10-31 22:00:00", "2017-11-30 22:00:00", "2017-12-31 22:00:00", "2018-01-31 22:00:00", "2018-02-28 22:00:00", "2018-03-31 21:00:00", "2018-04-30 21:00:00", "2018-05-31 21:00:00", "2018-06-30 21:00:00", "2018-07-31 21:00:00", "2018-08-31 21:00:00", "2018-09-30 21:00:00", "2018-10-31 22:00:00"], "y": [117, 104, 87, 137, 143, 128, 150, 147, 129, 153, 152, 127, 174, 147], "type": "scatter", "uid": "c25df439-4803-428f-94e2-a99d620414cb"}, {"hoverinfo": "y", "line": {"shape": "linear"}, "mode": "lines", "x": ["2017-09-30 21:00:00", "2017-10-31 22:00:00", "2017-11-30 22:00:00", "2017-12-31 22:00:00", "2018-01-31 22:00:00", "2018-02-28 22:00:00", "2018-03-31 21:00:00", "2018-04-30 21:00:00", "2018-05-31 21:00:00", "2018-06-30 21:00:00", "2018-07-31 21:00:00", "2018-08-31 21:00:00", "2018-09-30 21:00:00", "2018-10-31 22:00:00"], "y": [88, 95, 55, 90, 89, 79, 103, 75, 91, 110, 124, 107, 137, 118], "type": "scatter", "uid": "64f61cff-8c5d-4d3e-80ff-3ea6ef0a3af7"}, {"hoverinfo": "y", "line": {"shape": "linear"}, "mode": "lines", "x": ["2017-09-30 21:00:00", "2017-10-31 22:00:00", "2017-11-30 22:00:00", "2017-12-31 22:00:00", "2018-01-31 22:00:00", "2018-02-28 22:00:00", "2018-03-31 21:00:00", "2018-04-30 21:00:00", "2018-05-31 21:00:00", "2018-06-30 21:00:00", "2018-07-31 21:00:00", "2018-08-31 21:00:00", "2018-09-30 21:00:00", "2018-10-31 22:00:00"], "y": [63, 57, 36, 52, 46, 47, 47, 45, 40, 40, 48, 40, 46, 52], "type": "scatter", "uid": "a01b86d3-b6a4-4fa9-b8e8-fc1b3c9dd450"}, {"hoverinfo": "y", "line": {"shape": "linear"}, "mode": "lines", "x": ["2017-09-30 21:00:00", "2017-10-31 22:00:00", "2017-11-30 22:00:00", "2017-12-31 22:00:00", "2018-01-31 22:00:00", "2018-02-28 22:00:00", "2018-03-31 21:00:00", "2018-04-30 21:00:00", "2018-05-31 21:00:00", "2018-06-30 21:00:00", "2018-07-31 21:00:00", "2018-08-31 21:00:00", "2018-09-30 21:00:00", "2018-10-31 22:00:00"], "y": [22, 31, 19, 30, 26, 21, 32, 23, 18, 28, 39, 24, 39, 35], "type": "scatter", "uid": "d00e4f5d-ae3c-44e4-ae83-b08c8dd70b8f"}, {"hoverinfo": "y", "line": {"shape": "linear"}, "mode": "lines", "x": ["2017-09-30 21:00:00", "2017-10-31 22:00:00", "2017-11-30 22:00:00", "2017-12-31 22:00:00", "2018-01-31 22:00:00", "2018-02-28 22:00:00", "2018-03-31 21:00:00", "2018-04-30 21:00:00", "2018-05-31 21:00:00", "2018-06-30 21:00:00", "2018-07-31 21:00:00", "2018-08-31 21:00:00", "2018-09-30 21:00:00", "2018-10-31 22:00:00"], "y": [44, 52, 39, 55, 56, 44, 52, 61, 54, 57, 52, 45, 71, 52], "type": "scatter", "uid": "823f8aef-dd1e-40f6-b79a-740fb99a016e"}], {"annotations": [{"font": {"family": "Sans Serif", "size": 12}, "showarrow": false, "text": "java_count", "x": 0, "xanchor": "right", "xref": "paper", "y": 167, "yanchor": "middle"}, {"font": {"family": "Sans Serif", "size": 12}, "showarrow": false, "text": "php_count", "x": 0, "xanchor": "right", "xref": "paper", "y": 117, "yanchor": "middle"}, {"font": {"family": "Sans Serif", "size": 12}, "showarrow": false, "text": "js_count", "x": 0, "xanchor": "right", "xref": "paper", "y": 88, "yanchor ...

# %%
from IPython.core.display import HTML
with open('../resources/styles/python_style.css', 'r') as f:
    style = f.read()
HTML(style)
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Noto+Sans|Source+Sans+Pro');
#
# .nbviewer {
#     background: #295880;
# }
#
# #navbar, ol.breadcrumb {
#     background-color: #fbfbfb;
# }
#
# footer {
#     background-color: #fbfbfb;
#     color: #172027;
# }
#
# #notebook {
#     background-color: #295880;
# }
#
# #notebook-container {
#     background: #1c3b56;
#     border-radius: 4px;
# }
#
# /* Headings */
# div#notebook-container h1, h2, h3, h4, h5 {
#     color: #FBFBFB;
# }
#
# .text_cell_render h1 {
#     font-family: 'SourceSansPro', sans-serif;
#     font-size: 4em;
# }
#
# .text_cell_render h2 {
#     font-family: 'SourceSansPro', sans-serif;
#     font-size: 3em;
# }
#
# .text_cell_render h3 {
#     font-family: 'SourceSansPro', sans-serif;
#     font-size: 2em;
# }
#
# .text_cell_render h4 {
#     font-family: 'SourceSansPro', sans-serif;
#     font-size: 1.5em;
# }
#
# div.rendered_html > h5 {
#     font-family: 'SourceSansPro', sans-serif;
#     font-size: 1.2em;
#     font-weight: normal;
#     font-style: normal;
# }
#
# /* Use for image and chart captions */
# div.rendered_html > h6 {
#     display: block;
#     color: #cac8c9;
#     font-family: 'SourceSansPro', sans-serif;
#     text-align: center;
#     font-size: 0.9em;
#     line-height: 1.5em;
#     font-weight: normal;
#     max-width: 520px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div#notebook-container p {
#     font-family: 'SourceSansPro', sans-serif;
#     font-size: 1.2em;
#     line-height: 1.3em;
#     text-indent: 2em;
#     color: #cac8c9;
# }
#
# /* Lists */
# ol, ul {
#     font-family: 'SourceSansPro', sans-serif;
#     font-size: 1.2em;
#     line-height: 1.4em;
#     color: #cac8c9;
# }
#
# div.input_prompt {
#     color: #ffd343;
# }
#
# div.output_prompt {
#     color: #ffd343;
# }
#
# div.text_cell code {
#     background: transparent;
#     color: #fcfcfc;
#     font-family: 'NotoSans', monospace;
# }
#
# div.cell {
#     padding-right: 15px;
# }
#
# div.input_area {
#     border: none;
#     padding: 8px 16px 8px 16px;
#     overflow-x: hidden;
#     overflow-y: hidden;
#     background-color: #172027;
#     -webkit-box-shadow: inset 10px -5px 20px 0px rgba(8,10,10,2);
#     -moz-box-shadow: inset 10px -5px 20px 0px rgba(8,10,10,2);
#     box-shadow: inset 10px -5px 20px 0px rgba(8,10,10,2);
# }
#
# div.cell.rendered.selected {
#     border-width: 0;
#     border-radius: 8px;
#     border-radius: 8px 8px 8px 8px;
#     -moz-border-radius: 8px 8px 8px 8px;
#     -webkit-border-radius: 8px 8px 8px 8px;
#     border: 1px outset #185b91;
#     background: -webkit-linear-gradient(bottom, #2A587E, #4392D5);
#     background: -moz-linear-gradient(bottom, #2A587E, #4392D5);
#     background: linear-gradient(to top, #2A587E, #4392D5);
#     -webkit-box-shadow: 0px 4px 10px 2px rgba(4,5,5,0.5);
#     -moz-box-shadow: 0px 4px 10px 2px rgba(4,5,5,0.5);
#     box-shadow: 0px 4px 10px 2px rgba(4,5,5,0.5);
# }
#
# div.cell.selected::before, div.cell.selected.jupyter-soft-selected::before {
#     position: absolute;
#     display: block;
#     width: 0;
#     height: calc(100% - 2px);
#     content: '';
# }
#
# div.text_cell_render img {
#     max-height: 520px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.output_area img, div.output_area svg {
#     max-height: 520px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.rendered_html hr {
#     border: 0;
#     height: 1px;
#     background-image: -webkit-linear-gradient(left, #f0f0f0, #8c8b8b, #f0f0f0);
#     background-image: -moz-linear-gradient(left, #f0f0f0, #8c8b8b, #f0f0f0);
#     background-image: -ms-linear-gradient(left, #f0f0f0, #8c8b8b, #f0f0f0);
#     background-image: -o-linear-gradient(left, #f0f0f0, #8c8b8b, #f0f0f0);
# }
#
# div.output_text pre {
#     font-family: 'NotoSans', monospace;
#     font-size: 16px;
#     font-weight: 400;
#     color: #f0f0f0;
# }
#
# pre, textarea {
#     overflow: hidden;
# }
#
# div.rendered_html pre, code {
#     font-family: 'NotoSans', monospace;
#     font-size: 16px;
#     font-weight: 400;
#     color: #f0f0f0;
#     background-color: #1e2933;
# }
#
# /* Links */
# a.link--embedview {
#     display: none;
# }
#
# a:link {
#     color: #197b11;
# }
#
# a:visited {
#     color: #197b11;
# }
#
# a:hover {
#     color: #82b043;
# }
#
# a:focus {
#     color:#78797a;
# }
#
# a:active {
#     font-weight: bold;
#     color:#ffd343;
# }
#
# .rendered_html :link {
#     text-decoration: underline;
# }
#
# /* Table styles */
# table {
#     border: 1px solid #BF4D28;
# }
#
# .rendered_html table {
#     float:left;
#     width:100%;
#     border-collapse: collapse;
# }
#
# .rendered_html th {
#     text-align: left;
#     background-color: #E5E1D8;
# }
#
# .rendered_html td {
#     text-align: left;
# }
#
# .rendered_html table tr:nth-child(odd) {
#     background-color: #F0E4D5;
# }
#
# .rendered_html table tr:nth-child(even) {
#     background-color: #F5EDE1;
# }
#
# .rendered_html table tr:hover {
#     background-color: #BF4D28;
# }
#
# iframe {
#     border-width: 0;
# }
#
# .CodeMirror-vscrollbar,
# .CodeMirror-hscrollbar,
# .CodeMirror-scrollbar-filler,
# .CodeMirror-gutter-filler {
#     overflow-x: hidden;
#     overflow-y: hidden;
#     position: absolute;
#     z-index: 6;
#     display: none;
# }
#
# /* Colors for code highlighting */
# .CodeMirror pre {
#     font-family: 'NotoSans', monospace;
#     line-height: 1.6em;
# }
#
# .CodeMirror-code span.cm-keyword {
#     color: #1d8815;
# }
#
# .CodeMirror-code span.cm-variable {
#     color: #1d8815;
# }
#
# .CodeMirror-code span.cm-def {
#     color: #a06ba7;
# }
#
# .CodeMirror-code span.cm-property {
#     color: #82b043;
# }
#
# .CodeMirror-code span.cm-operator {
#     color: #1d8815;
# }
#
# .CodeMirror-code span.cm-string {
#     color: #cac8b4;
# }
#
# .CodeMirror-code span.cm-number {
#     color: #ffd34f;
# }
#
# .CodeMirror-code span.cm-comment {
#     color: #666666;
# }
#
# .CodeMirror-code span.cm-builtin {
#     color: #1d8815;
# }
#
# /* Code with no class applied (brackets mostly) */
# .CodeMirror-line > span {
#     color: #1d8815;
# }
#
# /* Styles for NBViewer */
# /* Built Ins */
# .highlight .kc,
# .highlight .kd,
# .highlight .kn,
# .highlight .nb {
#     color: #1d8815 !important;
# }
#
# /* Variables */
# .highlight .nn {
#     color: #1d8815 !important;
# }
#
# pre span.n {
#     color: #1d8815 !important;
# }
#
# /* Function Definition */
# .highlight .nf {
#     color: #a06ba7 !important;
# }
#
# /* Keywords */
# .highlight .ow {
#     color: #1d8815 !important;
# }
#
# /* Operator */
# .highlight .o {
#     color: #1d8815 !important;
# }
#
# /* All others */
# .highlight .p {
#     color: #1d8815 !important;
# }
#
# /* Strings */
# .highlight .s1 {
#     color: #cac8b4 !important;
# }
#
# /* Comments */
# .highlight .c1 {
#     color: #666666 !important;
# }
#
# /* Numbers */
# .highlight .mb,
# .highlight .mf,
# .highlight .mh,
# .highlight .mi,
# .highlight .mo {
#     color: #ffd34f !important;
# }
# </style>
