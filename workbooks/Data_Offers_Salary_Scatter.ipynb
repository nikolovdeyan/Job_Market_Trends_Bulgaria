# %% [markdown]
# ## Data Offers Salary Scatter Plot

# %%
import itertools
import psycopg2
import pandas as pd
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

from nbstyler import DATA_STYLE as DS

plotly.offline.init_notebook_mode(connected=True) # run at the start of every ipython notebook to use plotly.offline

# %matplotlib notebook
# %matplotlib inline
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ### Objectives
#
# Provide a customized scatter plot showing how the data jobs that have salary information provided relate to the averages on the job market.
#
# ### Data preparation

# %%
data_querystr = """SELECT
    subm_date, job_title, company_name, company_id, job_id, norm_salary, text_salary, job_contents
FROM v_full_data_offers_history"""

# %%
conn = psycopg2.connect('dbname=jobsbg')
data_df = pd.read_sql_query(data_querystr, conn, index_col='subm_date')
stats_df = pd.read_sql_query('SELECT * FROM v_salary_stats_monthly', conn, index_col='month_ts')
conn.close()

# %% [markdown]
# data_df contains all data jobs, but for this plot we are only going to use those that have salary information. By using the notna() method we filter only the rows in the data_df DataFrame where we have that info available.

# %%
data_df = data_df[data_df.norm_salary.notna()]

# %% [markdown]
# ### Preparing the background stats line

# %%
trace_med = go.Scatter(
    x=[w for w in stats_df.index],
    y=[v for v in stats_df['median']],
    mode='lines',
    showlegend=False,
    fill=None,
    line=dict(
        width=1.4,
        color='rgba(213, 145, 113, 0.5)',
    ),
    hoverinfo='none',
)

trace_q3 = go.Scatter(
    x=[w for w in stats_df.index],
    y=[v for v in stats_df.third_quartile],
    mode='lines',
    showlegend=False,
    fill=None,
    line=dict(
        width=0,
    ),
    hoverinfo='none',
)

trace_q1 = go.Scatter(
    x=[w for w in stats_df.index],
    y=[v for v in stats_df.first_quartile],
    mode='lines',
    showlegend=False,
    fill='tonexty',
    fillcolor='rgba(236, 213, 187, 0.6)',
    line=dict(
        width=0,
    ),
    hoverinfo='none',
)

# %% [markdown]
# #### Build a custom hoverbox label
#
# The `Scatter.hovertemplate` property described in the documentation is not available yet, so in order to create a custom hover box we can define our own template and wrap it in a function.

# %%
def hoverbox_builder(job):
    """Populates a text template to prepare a hoverbox from hovertext."""
    return f"\
<b>{job.job_title}</b><br>\
{job.Index.strftime('%d %b %Y')}<br>\
{job.company_name}<br>\
<b>{job.text_salary}</b> ➡ <i>(norm. {job.norm_salary:.0f} BGN)</i>"


hoverboxes = [hoverbox_builder(job) for job in data_df.itertuples()]

# %% [markdown]
# #### Build a marker generator

# %%
class MarkerBuilder:
    _allowed_colors = ['#C45E3A', '#0B7761', '#75AC95', '#E6AC27', '#AE90B9', '#2764E6']
    _allowed_symbols = ['star', 'pentagon', 'diamond', 'cross', 'triangle-up', 'hexagon', 'star', 'x']

    def __init__(self):
        self._active_markers = list(itertools.product(self._allowed_symbols, self._allowed_colors))
        self._max_symbol_index = len(self._active_markers) - 1
        self.tracked_company_ids = []

    def get_marker(self, company_id):
        if len(self.tracked_company_ids) >= self._max_symbol_index:
            return ('circle-open', '#80BCA3')
        if not str(company_id) in self.tracked_company_ids:
            self.tracked_company_ids.append(str(company_id))

        return self._active_markers[self.tracked_company_ids.index(str(company_id))]


mb = MarkerBuilder()
markers = [mb.get_marker(c) for c in data_df.company_id]

# %%
trace_datajobs = go.Scatter(
    x=[w for w in data_df.index],
    y=[v for v in data_df.norm_salary],
    mode='markers',
    showlegend=False,
    marker=dict(
        color=[opt[1] for opt in markers],
        symbol=[opt[0] for opt in markers],
        opacity=1,
        size=6,
    ),
    hoverinfo='text',
    hoveron='points',
    hovertext=hoverboxes,
    hoverlabel=dict(
        bgcolor=DS['colors']['bg2'],
        bordercolor=DS['colors']['fg2'],
        font=DS['chart_fonts']['text']
    ),
)

# %%
data = [trace_med, trace_q3, trace_q1, trace_datajobs]

# %%
layout = go.Layout(
    paper_bgcolor=DS['colors']['bg1'],
    plot_bgcolor=DS['colors']['bg1'],
    title='Data Offers Salary Scatter Plot',
    titlefont=DS['chart_fonts']['title'],
    font=DS['chart_fonts']['text'],
    autosize=True,
    hidesources=True,
    xaxis=dict(
        type='date',
        range=[min(stats_df.index), max(stats_df.index)],
        fixedrange=False,
        zerolinecolor=DS['colors']['fg2'],
        ticks='outside',
        tickmode='auto',
        nticks=len(stats_df.index),
        tickformat='%b,\n%Y',
    ),
    yaxis=dict(
        title='Normalized monthly salary',
        titlefont=DS['chart_fonts']['text'],
        type='linear',
        fixedrange=False,
        zerolinecolor=DS['colors']['fg2'],
        ticks='outside',
        tickwidth=1,
    ),
    hovermode='closest',
    hoverdistance=10,
)

# %%
fig = go.Figure(data=data, layout=layout)

plotly.offline.iplot(fig, filename='data_offers_scatter.html')
# Out:
# <div id="ba0fdbdb-e674-4470-a27c-394677848592" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ba0fdbdb-e674-4470-a27c-394677848592", [{"hoverinfo": "none", "line": {"color": "rgba(213, 145, 113, 0.5)", "width": 1.4}, "mode": "lines", "showlegend": false, "x": ["2017-09-01", "2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01", "2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01"], "y": [738.75, 750.0, 750.0, 750.0, 750.0, 750.0, 787.5, 787.5, 800.0, 825.0, 825.0, 801.25, 825.0, 825.0, 850.0, 850.0, 850.0, 862.5, 862.5], "type": "scatter", "uid": "b07bdd0a-d856-42a9-a123-a6939cd77df3"}, {"hoverinfo": "none", "line": {"width": 0}, "mode": "lines", "showlegend": false, "x": ["2017-09-01", "2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01", "2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01"], "y": [937.5, 950.0, 975.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1012.5, 1050.0, 1050.0, 1050.0, 1050.0, 1100.0, 1125.0, 1125.0, 1125.0, 1125.0, 1125.0], "type": "scatter", "uid": "20a3b461-340f-4768-82a3-88661e031987"}, {"fill": "tonexty", "fillcolor": "rgba(236, 213, 187, 0.6)", "hoverinfo": "none", "line": {"width": 0}, "mode": "lines", "showlegend": false, "x": ["2017-09-01", "2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01", "2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01"], "y": [599.63, 582.75, 600.0, 600.0, 600.0, 600.0, 615.0, 618.75, 637.5, 650.0, 650.0, 650.0, 650.0, 675.0, 675.0, 675.0, 675.0, 675.0, 680.0], "type": "scatter", "uid": "dd9199c7-b29e-4298-8e22-b5b6ed2108f1"}, {"hoverinfo": "text", "hoverlabel": {"bgcolor": "#faf0dc", "bordercolor": "#655643", "font": {"color": "#655643", "family": "Fira Sans Condensed", "size": 12}}, "hoveron": "points", "hovertext": ["<b>DB Developer (Database, ETL, Teradata)</b><br>05 Oct 2017<br>Sciant AD<br><b>\u043e\u0442 2800 \u0434\u043e 4100 BGN (\u041d\u0435\u0442\u043e)</b> \u27a1 <i>(norm. 3450 BGN)</i>", "<b>Senior Data Scientist</b><br>20 Oct 2017<br>TECHWORK.BG LTD.<br><b>\u043e\u0442 5000 \u0434\u043e 7000 BGN (\u041d\u0435\u0442\u043e)</b> \u27a1 <i>(norm. 6000 BGN)</i>", "<b>Business Intelligence Data Warehouse Architect with Redshift</b><br>24 Oct 2017<br>key2market EOOD<br><b>\u043e\u0442 5000 \u0434\u043e 8000 BGN (\u0411\u0440\u0443\u0442\u043e)</b> \u27a1 <i>(norm. 4875 BGN)</i>", "<b>Business Intelligence Data Warehouse Architect with Redshift</b><br>24 Oct 2017<br>key2market EOOD<br><b>\u043e\u0442 5000 \u0434\u043e 8000 BGN (\u0411\u0440\u0443\u0442\u043e)</b> \u27a1 <i>(norm. 4875 BGN)</i>", "<b>Business Intelligence Data Warehouse Architect with Redshift</b><br>24 Oct 2017<br>key2market EOOD<br><b>\u043e\u0442 5000 \u0434\u043e 8000 BGN (\u0411\u0440\u0443\u0442\u043e)</b> \u27a1 <i>(norm. 4875 BGN)</i>", "<b>Data Analyst with Tableau</b><br>24 Oct 2017<br>key2market EOOD<br><b>\u043e\u0442 4000 \u0434\u043e 6000 BGN (\u0411\u0440\u0443\u0442\u043e)</b> \u27a1 <i>(norm. 3750 BGN)</i>", "<b>Data Analyst with Tableau</b><br>24 Oct 2017<br>key2market EOOD<br><b>\u043e\u0442 4000 \u0434\u043e 6000 BGN (\u0411\u0440\u0443\u0442\u043e)</b> \u27a1 <i>(norm. 3750 BGN)</i>", "<b>Data Analyst with Tableau</b><br>24 Oct 2017<br>key2market EOOD<br><b>\u043e\u0442 4000 \u0434\u043e 6000 BGN (\u0411\u0440\u0443\u0442\u043e)</b> \u27a1 <i>(norm. 3750 BGN)</i>", "<b>JUNIOR DATA ANALYST</b><br>15 Nov 2017<br>\u0413\u0410\u041b\u0418\u0426\u0418\u042f \u041e\u041e\u04 ...

# %%
# Uncomment the line below to export an HTML version of the chart.
# plotly.offline.plot(fig, filename='data_offers_scatter.html', show_link=False)
# Out:
# 'file:///data/WORKSPACE/jpynb_Employment_Trends_Bulgaria/workbooks/data_offers_scatter.html'

# %%
from IPython.core.display import HTML
with open('../resources/styles/datum.css', 'r') as f:
    style = f.read()
HTML(style)
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Fira+Mono|Fira+Sans|Fira+Sans+Condensed|Fira+Sans+Extra+Condensed');
# @import url('https://fonts.googleapis.com/css?family=Merriweather|Merriweather+Sans');
#
# .nbviewer {
#     background-color: #E5E1D8;
# }
#
# #notebook {
#     background-color: #E5E1D8;
# }
#
# #notebook-container {
#     background-color: #FFFAF0;
#     max-width: 1200px;
#     border-radius: 4px;
#     padding: 60px 40px 40px 40px;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     -moz-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
# }
#
# /* Jupyter Notebook Header Styling */
# body > #header {
#     background-color:#fafafa;
# }
#
# #header #menubar #menus {
#     background-color:#fefefe;
# }
#
# /* Headings */
# .text_cell_render h1 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 900;
#     font-size: 3.4em;
#     text-indent: 22px;
#     text-shadow: 0 2px #FFFAF0, 0 3px #8c8b8b;
#     padding: 40px 0 12px 0;
# }
#
# .text_cell_render h2 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 600;
#     font-size: 2.4em;
#     text-indent: 22px;
#     padding: 40px 0 5px 0;
#     margin-bottom: 24px;
#     border-bottom: 1px solid #655643;
# }
#
# .text_cell_render h3 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 100;
#     font-size: 1.8em;
#     padding: 6px 0 0 0;
# }
#
# .text_cell_render h4 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 100;
#     font-size: 1.3em;
# }
#
# /* Use for subtitles and other non-headings */
# div.rendered_html > h5 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 200;
#     font-style: normal important!;
#     text-indent: 22px;
#     margin-top: 0.5em;
#     padding: 6px 0 6px 0;
#     border-bottom: 1px solid #655643;
#     border-top: 1px solid #655643;
# }
#
# /* Use for image and chart captions */
# div.rendered_html > h6 {
#     font-family: 'Merriweather Sans', sans-serif;
#     font-size: 0.9em;
#     line-height: 1.5em;
#     color: #cac8c9;
#     font-weight: normal;
#     max-width: 525px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div#notebook-container p {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 1.2em;
#     line-height: 1.3em;
#     color: #655643;
# }
#
# /* Plotly Exported Charts Styling */
# .js-plotly-plot .plotly,
# .js-plotly-plot .plotly div {
#     direction: ltr;
#     font-family: "Fira Sans Extra Condensed", verdana, arial, sans-serif;
# }
#
#
# /* Lists */
# ol, ul {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     line-height: 1.3em;
#     color: #655643;
# }
#
# div.input_prompt {
#     color: #aad0bc;
#     font-size: 0.7em;
# }
#
# div.output_prompt {
#     color: #aad0bc;
#     font-size: 0.7em;
# }
#
# div.output_subarea {
#     padding: 0;
# }
#
# div.text_cell code {
#     padding: 2px;
#     background-color: #E5E1D8;
#     color: #40362F;
#     font-family: 'Fira Mono', monospace;
#     font-size: 0.9em;
# }
#
# div.input_area {
#     background-color: #FFFAF0;
#     border: 1px solid #E5E1D8;
#     background: repeating-linear-gradient(135deg, #FFFAF0, #FFFAF0 5px, #F7F7ED 5px, #F7F7ED 10px);
# }
#
# div.cell.rendered.selected {
#     background: #F7F7ED;
#     border: 1px solid #38614F;
# }
#
# div.output_area img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.rendered_html pre, code {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 16px;
#     font-weight: 400;
#     color: #40362F;
#     background-color: #E5E1D8;
# }
#
# div.output_text pre {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 13px;
#     font-weight: 300;
#     color: #40362F;
# }
#
# pre, textarea {
#     overflow: hidden;
# }
#
# div.text_cell_render img {
#     max-height: 550px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.output output_scroll {
#     overflow-x: auto;
#     overflow-y: scroll;
#     max-height: 2000px;
# }
#
# div.rendered_html hr {
#     border: 0;
#     height: 1px;
#     background-color: #655643;
# }
#
# div.rendered_html pre, code {
#     color: #40362F;
#     background-color: #FFFAF0;
# }
#
# /* Links */
# a.link--embedview {
#     display: none;
# }
#
# a:link {
#     color: #293C34;
# }
#
# a:visited {
#     color: #293C34;
# }
#
# a:hover {
#     color: #557C6C;
# }
#
# a:focus {
#     color:#557C6C;
# }
#
# a:active {
#     font-weight: bold;
#     color:#80BCA3;
# }
#
# .rendered_html :link {
#     text-decoration: underline;
# }
#
# /* Colors for code highlighting */
# .CodeMirror pre {
#     font-family: 'Fira Mono', monospace;
#     font-size: 0.9em;
#     font-weight: 600;
#     letter-spacing: -2px;
# }
#
# .CodeMirror-code span.cm-keyword {
#     color: #5F362E;
# }
#
# .CodeMirror-code span.cm-variable {
#     color: #72614B;
# }
#
# .CodeMirror-code span.cm-property {
#     color: #72614B;
# }
#
# .CodeMirror-code span.cm-def {
#     color: #B64F4E;
# }
#
# .CodeMirror-code span.cm-operator {
#     color: #72614B;
# }
#
# .CodeMirror-code span.cm-string {
#     color: #0B7761;
# }
#
# .CodeMirror-code span.cm-number {
#     color: #2764E6;
# }
#
# .CodeMirror-code span.cm-comment {
#     color: #75AC95;
# }
#
# .CodeMirror-code span.cm-builtin {
#     color: #5F362E;
# }
#
# /* Code with no class applied (brackets mostly) */
# .CodeMirror-line > span {
#     color: #72614B;
# }
#
# /* Table styles */
# table {
#     border: 1px solid #BF4D28;
# }
#
# .rendered_html table {
#     float: middle;
#     border-collapse: collapse;
# }
#
# .rendered_html table th {
#     color: #40362F;
#     text-align: left;
#     background-color: #f2e6ce;
# }
#
# .rendered_html td {
#     color: #40362F;
#     text-align: left;
# }
#
# .rendered_html table tr:nth-child(odd) {
#     background-color: #F7F7ED;
# }
#
# .rendered_html table tr:nth-child(even) {
#     background-color: #FFFAF0;
# }
#
# .rendered_html table tr:hover {
#     background-color: #BF4D28;
# }
#
# iframe {
#     border-width: 0;
# }
# </style>
