# %% [markdown]
# ## Finance Requirements Deep Dive

# %%
import re
from collections import Counter
import psycopg2
import pandas as pd
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from IPython import display
from bs4 import BeautifulSoup as bs

import nltk
import string
from nltk.collocations import *
from nltk import FreqDist, tokenize
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()

from nltk.corpus import stopwords

from nbstyler import DATA_STYLE as s

plotly.offline.init_notebook_mode(connected=True) # run at the start of every ipython notebook to use plotly.offline

# %matplotlib notebook
# %matplotlib inline
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ### Data preparation

# %%
data_querystr = """SELECT * FROM v_full_finance_offers_history"""
conn = psycopg2.connect('dbname=jobsbg')
data_df = pd.read_sql_query(data_querystr, conn, index_col='subm_date')
conn.close()

# %%
data_df.head(5)
# Out:
#              subm_type   job_id  company_id  norm_salary  \
# subm_date
# 2017-09-27  submission  3994985      197145          NaN
# 2017-09-28  submission  3996359        4310          NaN
# 2017-09-28  submission  3996773      239646          NaN
# 2017-09-29  submission  3999032        1144          NaN
# 2017-10-02  submission  4000578      144532          NaN
#
#                                                     job_title  \
# subm_date
# 2017-09-27  Finance Application Support Analyst (Accountin...
# 2017-09-28  JUNIOR ACCOUNTANT - Structured Finance specialist
# 2017-09-28           Senior Project Manager, Finance Practice
# 2017-09-29                           Finance Reporting Expert
# 2017-10-02                           KYC & Finance Specialist
#
#                                             company_name text_salary  \
# subm_date
# 2017-09-27  ЛУИ ДРАЙФУС КОМОДИТИС СЪРВИСИЗ БЪЛГАРИЯ ЕООД        None
# 2017-09-28                             ТМФ СЪРВИСИЗ ЕООД        None
# 2017-09-28                          DataArt Bulgaria Ltd        None
# 2017-09-29                          Telenor Bulgaria EAD        None
# 2017-10-02                                  БУЛАНЕТ ЕООД        None
#
#                                                  job_contents
# subm_date
# 2017-09-27   <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 ...
# 2017-09-28   <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 ...
# 2017-09-28   <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 ...
# 2017-09-29   <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 ...
# 2017-10-02   <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 ...

# %%
def check_archive_content(job_id):
    conn = psycopg2.connect('dbname=jobsbg')
    cur = conn.cursor()
    query = f'SELECT * FROM f_get_offer_contents_by_job_id({job_id})'
    cur.execute(query)
    result = cur.fetchone()
    cur.close()
    conn.close()
    return result[0] 

# moved on to `build_nltk_freqdist()` to tackle bigrams and n-grams.
def build_counter(job_contents):
    contents_soup = bs(job_contents, 'html.parser')
    job_container = contents_soup.find('td', {'class': 'explainGray'}).parent.parent.parent.parent.parent
    if  job_container.find('style'):
        job_container.find('style').decompose()
    job_text = job_container.get_text().lower()
    job_wordlist = re.findall(r"['\w']+", job_text)
    counter = Counter(job_wordlist)
    return counter

def build_nltk_tokenlist(job_contents, stopwords):
    contents_soup = bs(job_contents, 'html.parser')
    job_container = contents_soup.find('td', {'class': 'explainGray'}).parent.parent.parent.parent.parent
    if  job_container.find('style'):
        job_container.find('style').decompose()
    job_text = job_container.get_text().lower() 
    nltk_ready = [word.lower() for word in tokenize.word_tokenize(job_text) if word.lower() not in stoplist and not word.isdigit()]
    return nltk_ready

def calc_nltk_bigrams_fdist(wlist):
    bigrams = nltk.bigrams(wlist)
    fdist = nltk.FreqDist(bigrams)
    return fdist
    
def calc_nltk_trigrams_fdist(wlist):
    trigrams = nltk.trigrams(wlist)
    fdist = nltk.FreqDist(trigrams)
    return fdist

# %% [markdown]
# #### Counting individual word occurrencies (depr)
#
# 1. Get soup
# 2. Get `.explainGray` and traverse up the tree 5 times. This is the job contents table.
# 3. Remove any injected styles from the job contents.

# %%
instance5 = data_df.iloc[10:11].job_contents.values
instance5_str = instance5[0]
instance5_soup = bs(instance5_str, 'html.parser')
job_container_table = instance5_soup.find('td', {'class': 'explainGray'}).parent.parent.parent.parent.parent

# %%
# remove style tag and its contents
job_container_table.find('style').decompose()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-138be9da900c> in <module>
#       1 # remove style tag and its contents
# ----> 2 job_container_table.find('style').decompose()
#
# AttributeError: 'NoneType' object has no attribute 'decompose'

# %% [markdown]
# 4. Get only the text of the tags
# 5. Lower and split to prepare the list for the Counter
# 6. Check result

# %%
job_text = job_container_table.get_text().lower()

# %% [markdown]
# #### Calculate common words, bigrams and trigrams

# %%
stopwords_bg = ['за', 'на', 'в', 'и', 'с', 'със', 'не', 'да', 'без', 'по', 'обяви', 'принтирай', 'обява',
               'обявата', 'работно', 'време', 'всички', 'тази', 'разглеждания', 'проблем', 'визитка', '--', 
               'добави', 'моите', 'известия', 'запази', 'бележника']
stoplist = stopwords.words('english') + stopwords_bg + list(string.punctuation)
stoplist = set(stoplist)

# %%
# %%time
token_contents = [build_nltk_tokenlist(jc, stoplist) for jc in data_df.job_contents]
# Out:
# CPU times: user 8.9 s, sys: 0 ns, total: 8.9 s
# Wall time: 8.92 s

# %%
# %%time

data_bigrams = [calc_nltk_bigrams_fdist(tc) for tc in token_contents]
result_bigrams = sum(data_bigrams, FreqDist())
# Out:
# CPU times: user 7.5 s, sys: 95.1 ms, total: 7.6 s
# Wall time: 7.6 s

# %%
result_bigrams.most_common(100)
# Out:
# [(('известие', 'нови'), 1084),
#  (('месторабота', 'софия'), 502),
#  (('работа', 'пълно'), 489),
#  (('постоянна', 'работа'), 470),
#  (('нови', 'фирма/организация'), 419),
#  (('фирма/организация', 'директно'), 419),
#  (('директно', 'търсеща'), 419),
#  (('търсеща', 'служители'), 419),
#  (('служители', 'повече'), 419),
#  (('софия', 'постоянна'), 400),
#  (('българия', 'еоод'), 367),
#  (('пълно', 'известие'), 305),
#  (('finance', 'manager'), 219),
#  (('candidates', 'contacted'), 218),
#  (('нови', 'finance'), 217),
#  (('еоод', 'известие'), 208),
#  (('university', 'degree'), 199),
#  (('bulgaria', 'ead'), 181),
#  (('finance', 'accounting'), 181),
#  (('инграм', 'микро'), 180),
#  (('микро', 'есесси'), 180),
#  (('есесси', 'емеа'), 180),
#  (('емеа', 'еоод'), 180),
#  (('short-listed', 'candidates'), 177),
#  (('skills', '•'), 172),
#  (('communication', 'skills'), 169),
#  (('\uf451вижте', 'компанията'), 168),
#  (('компанията', 'месторабота'), 167),
#  (('bulgaria', 'eood'), 167),
#  (('•', 'excellent'), 163),
#  (('подходяща', 'кандидати'), 159),
#  (('кандидати', 'малък'), 159),
#  (('малък', 'или'), 159),
#  (('или', 'опит'), 159),
#  (('finance', 'assistant'), 159),
#  (('finance', 'analyst'), 154),
#  (('ability', 'work'), 153),
#  (('working', 'environment'), 153),
#  (('personal', 'data'), 151),
#  (('ms', 'office'), 149),
#  (('ingram', 'micro'), 147),
#  (('considered', 'advantage'), 146),
#  (('пълно', 'подходяща'), 144),
#  (('please', 'send'), 143),
#  (('applications', 'treated'), 143),
#  (("'input", 'name='), 141),
#  (('name=', "''"), 141),
#  (('пи', 'пи'), 136),
#  (('пи', 'ди'), 136),
#  (('ди', 'българия'), 136),
#  (('strict', 'confidentiality'), 135),
#  (('еоод', 'месторабота'), 134),
#  (('опит', 'известие'), 126),
#  (('years', 'experience'), 125),
#  (('cv', 'english'), 124),
#  (('finance', 'team'), 123),
#  (('coca-cola', 'european'), 120),
#  (('european', 'partners'), 120),
#  (('•', 'strong'), 119),
#  (('към', 'кандидатите'), 116),
#  (('requirements', '•'), 115),
#  (('нови', 'агенция'), 115),
#  (('агенция', 'подбор'), 115),
#  (('подбор', 'персонал'), 115),
#  (('персонал', 'c'), 115),
#  (('c', 'изцяло'), 115),
#  (('изцяло', 'безплатнa'), 115),
#  (('безплатнa', 'услугa'), 115),
#  (('услугa', 'към'), 115),
#  (('кандидатите', 'повече'), 115),
#  (('attention', 'detail'), 112),
#  (('treated', 'strict'), 112),
#  (('analytical', 'skills'), 111),
#  (('bulgaria', 'ltd.'), 107),
#  (('exl', 'service'), 103),
#  (('adecco', 'bulgaria'), 102),
#  (('подходяща', 'студенти'), 100),
#  (('services', 'bulgaria'), 100),
#  (('service', 'exlservice'), 100),
#  (('exlservice', 'bulgaria'), 100),
#  (('•', 'experience'), 99),
#  (('•', 'good'), 97),
#  (('finance', 'department'), 97),
#  (('responsibilities', '•'), 95),
#  (('advantage', '•'), 95),
#  (('false', "'input"), 94),
#  (("''", '.is'), 94),
#  (('.is', 'checked'), 94),
#  (('return', 'false'), 94),
#  (("''", 'company_privacy_consent'), 94),
#  (('company_privacy_consent', "''"), 94),
#  (('.show', 'else'), 94),
#  (('★★★', 'finance'), 92),
#  (('contacted', 'applications'), 92),
#  (('•', 'ability'), 91),
#  (('★★★★★', 'finance'), 90),
#  (('english', 'language'), 90),
#  (('skills', 'ability'), 89),
#  (('send', 'cv'), 88),
#  (('decision', 'making'), 87)]

# %%
# %%time

data_trigrams = [calc_nltk_trigrams_fdist(tc) for tc in token_contents]
result_trigrams = sum(data_trigrams, FreqDist())
# Out:
# CPU times: user 1min, sys: 3.39 ms, total: 1min
# Wall time: 1min

# %%
# %%time

data_words = [FreqDist(tc) for tc in token_contents]
result_words = sum(data_words, FreqDist())
# Out:
# CPU times: user 6.07 s, sys: 1 µs, total: 6.07 s
# Wall time: 6.08 s

# %%
result_words.most_common(150)
# Out:
# [('data', 11119),
#  ('•', 7483),
#  ('business', 5251),
#  ('experience', 4354),
#  ('team', 3501),
#  ('нови', 3220),
#  ('известие', 3184),
#  ('skills', 3081),
#  ('work', 2912),
#  ('company', 2466),
#  ('development', 2274),
#  ('bi', 2251),
#  ('bulgaria', 2185),
#  ('english', 2177),
#  ('analyst', 2137),
#  ('reporting', 2124),
#  ('работа', 1915),
#  ('knowledge', 1889),
#  ('’', 1783),
#  ('requirements', 1744),
#  ('management', 1703),
#  ('excellent', 1687),
#  ('месторабота', 1598),
#  ('пълно', 1598),
#  ('кандидатствай', 1598),
#  ('повече', 1590),
#  ('еоод', 1565),
#  ('постоянна', 1563),
#  ('working', 1535),
#  ('sql', 1506),
#  ('analysis', 1497),
#  ('софия', 1492),
#  ('solutions', 1478),
#  ("''", 1473),
#  ('services', 1418),
#  ('support', 1397),
#  ('intelligence', 1397),
#  ('information', 1393),
#  ('new', 1374),
#  ('служители', 1374),
#  ('–', 1372),
#  ('environment', 1360),
#  ('фирма/организация', 1348),
#  ('директно', 1348),
#  ('търсеща', 1348),
#  ('ability', 1348),
#  ('personal', 1344),
#  ('tools', 1317),
#  ('българия', 1249),
#  ('us', 1233),
#  ('strong', 1231),
#  ('technical', 1223),
#  ('reports', 1222),
#  ('candidates', 1220),
#  ('design', 1161),
#  ('clients', 1112),
#  ('analytical', 1094),
#  ('good', 1086),
#  ('looking', 1052),
#  ('communication', 1040),
#  ('ref.', 1016),
#  ('systems', 1016),
#  ('professional', 1015),
#  ('develop', 1012),
#  ('opportunity', 1007),
#  ('process', 991),
#  ('developer', 986),
#  ('office', 984),
#  ('applications', 982),
#  ('provide', 974),
#  ('degree', 962),
#  ('people', 958),
#  ('offer', 958),
#  ('данни', 955),
#  ('quality', 950),
#  ('software', 944),
#  ('career', 939),
#  ('projects', 936),
#  ('international', 935),
#  ('responsibilities', 911),
#  ('technologies', 905),
#  ('using', 904),
#  ('etl', 899),
#  ('one', 896),
#  ('financial', 881),
#  ('position', 880),
#  ('part', 865),
#  ('ltd.', 858),
#  ('excel', 849),
#  ('global', 845),
#  ('best', 841),
#  ('от', 836),
#  ('please', 833),
#  ('understanding', 820),
#  ('years', 816),
#  ('join', 811),
#  ('performance', 794),
#  ('оод', 793),
#  ('role', 791),
#  ('eood', 781),
#  ('sofia', 780),
#  ('cv', 770),
#  ('компанията', 768),
#  ('analytics', 766),
#  ('project', 756),
#  ('database', 747),
#  ('technology', 741),
#  ('leading', 739),
#  ('world', 727),
#  ('advantage', 726),
#  ('★★★★★', 702),
#  ('send', 696),
#  ('contacted', 694),
#  ('warehouse', 692),
#  ('job', 690),
#  ('service', 689),
#  ('processes', 686),
#  ('application', 676),
#  ('opportunities', 675),
#  ('language', 672),
#  ('teams', 661),
#  ('customer', 661),
#  ('market', 659),
#  ('based', 658),
#  ('\uf451вижте', 657),
#  ('подходяща', 656),
#  ('eye', 656),
#  ('confidentiality', 655),
#  ('help', 652),
#  ('well', 649),
#  ('etc', 648),
#  ('deliver', 640),
#  ('written', 639),
#  ('b', 636),
#  ('training', 626),
#  ('client', 625),
#  ('short-listed', 622),
#  ('science', 621),
#  ('related', 619),
#  ('additional', 617),
#  ('ltd', 614),
#  ('еад', 613),
#  ('testing', 611),
#  ('research', 609),
#  ('test', 608),
#  ('protection', 608),
#  ('specialist', 604),
#  ('err_job', 604),
#  ('false', 604),
#  ('err_privacy', 604)]

# %%
result_bigrams.most_common(150)
# Out:
# [(('известие', 'нови'), 3184),
#  (('работа', 'пълно'), 1578),
#  (('постоянна', 'работа'), 1563),
#  (('месторабота', 'софия'), 1451),
#  (('нови', 'фирма/организация'), 1348),
#  (('фирма/организация', 'директно'), 1348),
#  (('директно', 'търсеща'), 1348),
#  (('търсеща', 'служители'), 1348),
#  (('служители', 'повече'), 1348),
#  (('софия', 'постоянна'), 1318),
#  (('business', 'intelligence'), 1256),
#  (('data', 'analyst'), 1134),
#  (('пълно', 'известие'), 989),
#  (('personal', 'data'), 887),
#  (('data', 'warehouse'), 664),
#  (('candidates', 'contacted'), 657),
#  (('\uf451вижте', 'компанията'), 657),
#  (('компанията', 'месторабота'), 653),
#  (('българия', 'еоод'), 641),
#  (('b', 'eye'), 636),
#  (('communication', 'skills'), 605),
#  (('short-listed', 'candidates'), 593),
#  (('bulgaria', 'eood'), 489),
#  (("'input", 'name='), 453),
#  (('name=', "''"), 453),
#  (('strict', 'confidentiality'), 447),
#  (('cv', 'english'), 436),
#  (('computer', 'science'), 427),
#  (('treated', 'strict'), 403),
#  (('big', 'data'), 401),
#  (('data', 'analysis'), 398),
#  (('пълно', 'подходяща'), 392),
#  (('years', 'experience'), 386),
#  (('please', 'send'), 377),
#  (('еоод', 'известие'), 370),
#  (('send', 'us'), 366),
#  (('българия', 'еад'), 364),
#  (('applications', 'treated'), 360),
#  (('university', 'degree'), 359),
#  (('reporting', 'analyst'), 356),
#  (('health', 'insurance'), 354),
#  (('english', 'language'), 351),
#  (('подходяща', 'кандидати'), 349),
#  (('кандидати', 'малък'), 349),
#  (('малък', 'или'), 349),
#  (('или', 'опит'), 349),
#  (('skills', '•'), 346),
#  (('bulgaria', 'ead'), 336),
#  (('data', 'protection'), 335),
#  (('eye', 'ltd.'), 318),
#  (('software', 'development'), 316),
#  (('•', 'experience'), 315),
#  (('sql', 'server'), 313),
#  (('best', 'practices'), 309),
#  (('подходяща', 'студенти'), 305),
#  (('work', 'environment'), 302),
#  (('false', "'input"), 302),
#  (("''", '.is'), 302),
#  (('.is', 'checked'), 302),
#  (('return', 'false'), 302),
#  (("''", 'company_privacy_consent'), 302),
#  (('company_privacy_consent', "''"), 302),
#  (('.show', 'else'), 302),
#  (('нови', 'data'), 295),
#  (('considered', 'advantage'), 283),
#  (('data', 'quality'), 280),
#  (('us', 'cv'), 278),
#  (('join', 'team'), 275),
#  (('professional', 'growth'), 275),
#  (('ability', 'work'), 271),
#  (('лични', 'данни'), 271),
#  (('career', 'development'), 270),
#  (('data', 'management'), 266),
#  (('•', 'good'), 263),
#  (('contacted', 'applications'), 257),
#  (('remuneration', 'package'), 255),
#  (('подбор', 'персонал'), 253),
#  (('еоод', 'месторабота'), 252),
#  (('competitive', 'salary'), 252),
#  (('skills', 'ability'), 252),
#  (('си', 'екс'), 248),
#  (('екс', 'джи'), 248),
#  (('джи', 'оод'), 248),
#  (('main', 'responsibilities'), 248),
#  (('reporting', 'specialist'), 248),
#  (('•', 'excellent'), 241),
#  (('experian', 'bulgaria'), 241),
#  (('ltd.', 'известие'), 239),
#  (('data', 'engineer'), 238),
#  (('strong', 'analytical'), 237),
#  (('агенция', 'подбор'), 233),
#  (('опит', 'известие'), 232),
#  (('•', 'strong'), 231),
#  (('студенти', 'подходяща'), 231),
#  (('data', 'scientist'), 231),
#  (('нови', 'агенция'), 231),
#  (('персонал', 'c'), 231),
#  (('c', 'изцяло'), 231),
#  (('изцяло', 'безплатнa'), 231),
#  (('безплатнa', 'услугa'), 231),
#  (('услугa', 'към'), 231),
#  (('към', 'кандидатите'), 231),
#  (('кандидатите', 'повече'), 231),
#  (('part', 'team'), 229),
#  (('data', 'analytics'), 227),
#  (('сървисиз', 'българия'), 225),
#  (('защита', 'лични'), 224),
#  (('experience', 'working'), 223),
#  (('understanding', 'data'), 223),
#  (('essential', 'requirements'), 218),
#  (('additional', 'health'), 217),
#  (('master', 'data'), 214),
#  (('bi', 'developer'), 214),
#  (('join', 'us'), 214),
#  (('analytical', 'skills'), 213),
#  (('knowledge', 'experience'), 212),
#  (('developer', 'b'), 212),
#  (('machine', 'learning'), 208),
#  (('power', 'bi'), 207),
#  (('bulgaria', 'ltd.'), 206),
#  (('analyst', 'english'), 205),
#  (('езици', 'английски'), 204),
#  (('problem', 'solving'), 202),
#  (('bachelor', '’'), 201),
#  (('design', 'develop'), 199),
#  (('protection', 'personal'), 198),
#  (('degree', 'computer'), 197),
#  (('ltd.', 'месторабота'), 197),
#  (('market', 'research'), 196),
#  (('bi', 'analyst'), 195),
#  (('английски', 'известие'), 194),
#  (('оод', 'известие'), 192),
#  (('•', 'ability'), 192),
#  (('competitive', 'remuneration'), 191),
#  (('etl', 'developer'), 187),
#  (('world', '’'), 182),
#  (('new', 'office'), 182),
#  (('send', 'cv'), 182),
#  (('data', 'processing'), 179),
#  (('★★★★★', 'data'), 177),
#  (('technical', 'skills'), 176),
#  (('personal', 'information'), 176),
#  (('business', 'requirements'), 175),
#  (('’', 'degree'), 174),
#  (('attention', 'detail'), 173),
#  (('dxc', 'technology'), 172),
#  (('eood', 'известие'), 171),
#  (('fluency', 'english'), 171),
#  (('written', 'verbal'), 168),
#  (('degree', 'mathematics'), 167)]

# %%
result_trigrams.most_common(30)
# Out:
# [(('постоянна', 'работа', 'пълно'), 1546),
#  (('известие', 'нови', 'фирма/организация'), 1348),
#  (('нови', 'фирма/организация', 'директно'), 1348),
#  (('фирма/организация', 'директно', 'търсеща'), 1348),
#  (('директно', 'търсеща', 'служители'), 1348),
#  (('търсеща', 'служители', 'повече'), 1348),
#  (('софия', 'постоянна', 'работа'), 1318),
#  (('месторабота', 'софия', 'постоянна'), 1316),
#  (('работа', 'пълно', 'известие'), 989),
#  (('пълно', 'известие', 'нови'), 989),
#  (('\uf451вижте', 'компанията', 'месторабота'), 653),
#  (('компанията', 'месторабота', 'софия'), 591),
#  (('short-listed', 'candidates', 'contacted'), 504),
#  (("'input", 'name=', "''"), 453),
#  (('treated', 'strict', 'confidentiality'), 389),
#  (('работа', 'пълно', 'подходяща'), 376),
#  (('еоод', 'известие', 'нови'), 370),
#  (('подходяща', 'кандидати', 'малък'), 349),
#  (('кандидати', 'малък', 'или'), 349),
#  (('малък', 'или', 'опит'), 349),
#  (('applications', 'treated', 'strict'), 329),
#  (('b', 'eye', 'ltd.'), 318),
#  (("''", '.is', 'checked'), 302),
#  (('name=', "''", 'company_privacy_consent'), 302),
#  (("''", 'company_privacy_consent', "''"), 302),
#  (('известие', 'нови', 'data'), 295),
#  (('пълно', 'подходяща', 'студенти'), 274),
#  (('candidates', 'contacted', 'applications'), 255),
#  (('send', 'us', 'cv'), 254),
#  (('contacted', 'applications', 'treated'), 252)]

# %%
# Uncomment the line below to export an HTML version of the chart.
# plotly.offline.plot(fig, filename = 'data_offers_requirements.html')

# %%
from IPython.core.display import HTML
with open('../resources/styles/datum.css', 'r') as f:
    style = f.read()
HTML(style)
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Fira+Mono|Fira+Sans|Fira+Sans+Condensed|Fira+Sans+Extra+Condensed');
# @import url('https://fonts.googleapis.com/css?family=Merriweather|Merriweather+Sans');
#
# .nbviewer {
#     background-color: #FFFAF0;
# }
#
# #notebook-container {
#     background-color: #FFFAF0
# }
#
# /* Headings */
# .text_cell_render h1 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 900;
#     font-size: 3.4em;
#     text-shadow: 0 2px #FFFAF0, 0 3px #8c8b8b;
#     padding: 30px 0 25px 0;
# }
#
# .text_cell_render h2 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 400;
#     font-size: 3em;
#     padding-bottom: 8px;
#     margin-bottom: 30px;
#     border-bottom: 4px inset #655643;
# }
#
# .text_cell_render h3 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 100;
#     font-size: 1.8em;
# }
#
# .text_cell_render h4 {
#     color: #655643;
#     font-family: 'Merriweather', serif;
#     font-weight: 100;
#     font-size: 1.4em;
# }
#
# /* Use for subtitles and other non-headings */
# div.rendered_html > h5 {
#     color: #655643;
#     font-family: 'Merriweather Sans', sans-serif;
#     font-size: 1.0em;
#     font-weight: normal;
#     font-style: normal;
#     margin-top: 0.5em;
# }
#
# /* Use for image and chart captions */
# div.rendered_html > h6 {
#     font-family: 'Merriweather Sans', sans-serif;
#     font-size: 0.9em;
#     line-height: 1.5em;
#     color: #cac8c9;
#     font-weight: normal;
#     max-width: 520px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div#notebook-container p {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 1.2em;
#     line-height: 1.3em;
#     text-indent: 1em;
#     color: #40362F;
# }
#
# /* Lists */
# ol, ul {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     line-height: 1.4em;
#     color: #40362F;
# }
#
#
# div.input_prompt {
#     color: #40362F;
# }
#
# div.output_prompt {
#     color: #40362F;
# }
#
# div.text_cell code {
#     background: transparent;
#     color: #40362F;
#     font-family: 'Fira Mono', monospace;
# }
#
# div.input_area {
#     background-color: #FFFAF0;
#     border: 1px solid #E5E1D8;
#     background: repeating-linear-gradient(135deg, #FFFAF0, #FFFAF0 5px, #F7F7ED 5px, #F7F7ED 10px);
# }
#
# div.cell.rendered.selected {
#     background: #E5E1D8;
#     border: 1px solid #38614F;
# }
#
# div.output_area img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.rendered_html pre, code {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 16px;
#     font-weight: 400;
#     color: #40362F;
#     background-color: #E5E1D8;
# }
#
# div.output_text pre {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 13px;
#     font-weight: 300;
#     color: #40362F;
# }
#
# pre, textarea {
#     overflow: hidden;
# }
#
# div.text_cell_render img {
#     max-height: 520px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.output output_scroll {
#     overflow-x: auto;
#     overflow-y: scroll;
#     max-height: 2000px;
# }
#
# div.rendered_html hr {
#     border: 0;
#     height: 2px;
#     background-color: #655643;
# }
#
# div.rendered_html pre, code {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 16px;
#     color: #40362F;
#     background-color: #FFFAF0;
# }
#
# /* Links */
# a.link--embedview {
#     display: none;
# }
#
# a:link {
#     color: #293C34;
# }
#
# a:visited {
#     color: #293C34;
# }
#
# a:hover {
#     color: #557C6C;
# }
#
# a:focus {
#     color:#557C6C;
# }
#
# a:active {
#     font-weight: bold;
#     color:#80BCA3;
# }
#
# .rendered_html :link {
#     text-decoration: underline;
# }
#
# /* Colors for code highlighting */
# .CodeMirror-code span.cm-keyword {
#     color: #557C6C;
# }
#
# .CodeMirror-code span.cm-variable {
#     color: #4C4138;
# }
#
# .CodeMirror-code span.cm-property {
#     color: #40362F;
# }
#
# .CodeMirror-code span.cm-operator {
#     color: #4C4138;
# }
#
# .CodeMirror-code span.cm-string {
#     color: #7F331B;
# }
#
# .CodeMirror-code span.cm-number {
#     color: #458C7A;
# }
#
# .CodeMirror-code span.cm-comment {
#     color: #557C6C;
# }
#
# .CodeMirror-code span.cm-builtin {
#     color: #557C6C;
# }
#
# /* Code with no class applied (brackets mostly) */
# .CodeMirror-line > span {
#     color: #557C6C;
# }
#
# /* Table styles */
# table {
#     border: 1px solid #BF4D28;
# }
#
# .rendered_html table {
#     float:left;
#     width:100%;
#     border-collapse: collapse;
# }
#
# .rendered_html table th {
#     text-align: left;
#     background-color: #E5E1D8;
# }
#
# .rendered_html td {
#     text-align: left;
# }
#
# .rendered_html table tr:nth-child(odd) {
#     background-color: #F0E4D5;
# }
#
# .rendered_html table tr:nth-child(even) {
#     background-color: #F5EDE1;
# }
#
# .rendered_html table tr:hover {
#     background-color: #BF4D28;
# }
#
# iframe {
#     border-width: 0;
# }
# </style>

# %% [markdown]
# https://nlp.stanford.edu/fsnlp/promo/colloc.pdf
