# %% [markdown]
# ## Historical Job Profiles Demand - Bar Chart

# %%
import datetime
import psycopg2
import pandas as pd
import ipywidgets as widgets
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

from nbstyler import DATA_STYLE as DS

plotly.offline.init_notebook_mode(connected=True)

# %matplotlib notebook
# %matplotlib inline
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ### Objectives
#
# Create a standard bar chart to gain insight into how the quantity of submitted data jobs is changing over time. Provide two separate time dimensions to aggregate the data on -- weekly and monthly. Provide a control to change between those two views.

# %% [markdown]
# ### Data Preparation
#
# Two separate queries were used to fetch prepared data from database views. A `Pandas.DataFrame` is constructed for each dataset and the first and last time periods for each dataset is dropped to remove incomplete time periods at the start and finish. This step also converts the `Pandas.DataFrame.Index` to `DateTimeIndex` to utilize the temporal methods that it exposes.

# %%
conn = psycopg2.connect("dbname=jobsbg")


# data analysis fs
da_montly = pd.read_sql_query("SELECT * FROM data_offers.do_count_monthly_by_title_kw('(data & (analyst | analysis | analytics | entry)) | ((анализатор | анализ | анализи | анализиране) & данни)')", 
                              conn, 
                              index_col='month_ts')
da_montly = da_montly[1:-1]
da_montly.index = pd.to_datetime(da_montly.index)


# business intelligence
bi_monthly = pd.read_sql_query("SELECT * FROM data_offers.do_count_monthly_by_title_kw('bi | ((business | data) & intelligence)')", 
                              conn, 
                              index_col='month_ts')
bi_monthly = bi_monthly[1:-1]
bi_monthly.index = pd.to_datetime(bi_monthly.index)


# data engineering
de_monthly = pd.read_sql_query("SELECT * FROM data_offers.do_count_monthly_by_title_kw('(data <-> (engineer | warehouse)) | dwh | etl')", 
                              conn, 
                              index_col='month_ts')
de_monthly = de_monthly[1:-1]
de_monthly.index = pd.to_datetime(de_monthly.index)

# data science
ds_monthly = pd.read_sql_query("SELECT * FROM data_offers.do_count_monthly_by_title_kw('data & (scientist | science)')", 
                              conn, 
                              index_col='month_ts')
ds_monthly = ds_monthly[1:-1]
ds_monthly.index = pd.to_datetime(ds_monthly.index)

# %%
print(f'Weekly dataframe head:{de_monthly.head(5)}')
# Out:
# Weekly dataframe head:            subm_count
# month_ts
# 2017-10-01          21
# 2017-11-01          15
# 2017-12-01          10
# 2018-01-01          18
# 2018-02-01          19

# %% [markdown]
# ### Implementing the Chart in Plotly
#
# Preparing two traces to represent our levels of aggregation for this chart. Which one will be visible will be controlled via buttons. The initial state is to show the `weekly_bar` trace by default.

# %%
da_bar = go.Bar(
    name='Data Analysis',
    x=[month for month in da_montly.index],
    y=[value for value in da_montly.subm_count],
    hoverinfo='y+name',
    showlegend=True,
    marker=dict(
        line=dict(
            width=1,
            color=DS['colorramp']['acc1'][-1]
        ),
        color=DS['colorramp']['acc1'][8],
        opacity=0.8,
    ),
    visible=True,
)

bi_bar = go.Bar(
    name='Business Intelligence',
    x=[month for month in bi_monthly.index],
    y=[value for value in bi_monthly.subm_count],
    hoverinfo='y+name',
    showlegend=True,
    marker=dict(
        line=dict(
            width=1,
            color=DS['colorramp']['acc1'][-1]
        ),
        color=DS['colorramp']['acc1'][6],
        opacity=0.8,
    ),
    visible=True,
)

de_bar = go.Bar(
    name='Data Engineering',
    x=[month for month in de_monthly.index],
    y=[value for value in de_monthly.subm_count],
    hoverinfo='y+name',
    showlegend=True,
    marker=dict(
        line=dict(
            width=1,
            color=DS['colorramp']['acc1'][-1]
        ),
        color=DS['colorramp']['acc1'][4],
        opacity=0.8,
    ),
    visible=True,
)

ds_bar = go.Bar(
    name='Data Science',
    x=[month for month in ds_monthly.index],
    y=[value for value in ds_monthly.subm_count],
    hoverinfo='y+name',
    showlegend=True,
    marker=dict(
        line=dict(
            width=1,
            color=DS['colorramp']['acc1'][-1]
        ),
        color=DS['colorramp']['acc1'][2],
        opacity=0.8,
    ),
    visible=True,
)

data = [da_bar, bi_bar, de_bar, ds_bar]

# %% [markdown]
#  Plotly `updatemenus` defines buttons and interactions to make the chart interactive. Setting different hoverformats and titles for the different views.

# %% [markdown]
# Preparing the figure layout:

# %%
layout = go.Layout(
    paper_bgcolor=DS['colors']['bg1'],
    plot_bgcolor=DS['colors']['bg1'],
    title='Monthly Data Jobs by Job Profile',
    titlefont=DS['chart_fonts']['title'],
    font=DS['chart_fonts']['text'],
    autosize=True,
    showlegend=True,
    hidesources=True,
    legend=dict(orientation='h'),
    modebar=dict(orientation='h'),
    xaxis=dict(
        type='date',
        fixedrange=True,
        hoverformat='Week %W, %Y',
        ticks='outside',
        tickmode='auto',
        zerolinecolor=DS['colors']['fg2'],
    ),
    yaxis=dict(
        title='Number of submissions',
        fixedrange=True,
        ticks='outside',
        tickwidth=1,
        gridcolor=DS['colors']['bg3'],
    ),
    barmode='stack'
)

def myfunc():
    lalala
    return a

# %%
fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='data_offer_profiles_stacked_bar.html')
# Out:
# <div id="c2dc8648-cd16-4e8d-b42d-13728d01b244" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c2dc8648-cd16-4e8d-b42d-13728d01b244", [{"hoverinfo": "y+name", "marker": {"color": "#c45e3a", "line": {"color": "#8f391e", "width": 1}, "opacity": 0.8}, "name": "Data Analysis", "showlegend": true, "visible": true, "x": ["2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01", "2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01", "2019-04-01", "2019-05-01", "2019-06-01", "2019-07-01", "2019-08-01", "2019-09-01"], "y": [45, 39, 36, 35, 56, 42, 46, 67, 64, 60, 55, 48, 69, 58, 42, 75, 59, 64, 69, 77, 63, 77, 59, 55], "type": "bar", "uid": "144e6be9-d261-4c7d-af94-9c715bdd3f75"}, {"hoverinfo": "y+name", "marker": {"color": "#d0805f", "line": {"color": "#8f391e", "width": 1}, "opacity": 0.8}, "name": "Business Intelligence", "showlegend": true, "visible": true, "x": ["2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01", "2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01", "2019-04-01", "2019-05-01", "2019-06-01", "2019-07-01", "2019-08-01", "2019-09-01"], "y": [24, 20, 17, 33, 40, 31, 32, 46, 34, 40, 53, 44, 60, 51, 30, 55, 54, 48, 55, 57, 51, 56, 59, 57], "type": "bar", "uid": "4812a4ea-6978-4e59-923b-e5ad129520c6"}, {"hoverinfo": "y+name", "marker": {"color": "#dba284", "line": {"color": "#8f391e", "width": 1}, "opacity": 0.8}, "name": "Data Engineering", "showlegend": true, "visible": true, "x": ["2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01", "2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01", "2019-04-01", "2019-05-01", "2019-06-01", "2019-07-01", "2019-08-01", "2019-09-01"], "y": [21, 15, 10, 18, 19, 18, 22, 30, 20, 23, 24, 20, 37, 35, 25, 43, 32, 24, 27, 20, 20, 25, 28, 27], "type": "bar", "uid": "6cc9bbc9-27ea-448b-a856-076ec062e57b"}, {"hoverinfo": "y+name", "marker": {"color": "#e6c4a9", "line": {"color": "#8f391e", "width": 1}, "opacity": 0.8}, "name": "Data Science", "showlegend": true, "visible": true, "x": ["2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01", "2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01", "2019-04-01", "2019-05-01", "2019-06-01", "2019-07-01", "2019-08-01", "2019-09-01"], "y": [6, 7, 7, 10, 4, 5, 6, 5, 7, 5, 9, 6, 7, 6, 6, 10, 10, 14, 16, 17, 9, 11, 19, 10], "type": "bar", "uid": "8b0d8c3c-1f74-497c-8ac1-999d21c9ada3"}], {"autosize": true, "barmode": "stack", "font": {"color": "#655643", "family": "Fira Sans Condensed", "size": 12}, "hidesources": true, "legend": {"orientation": "h"}, "modebar": {"orientation": "h"}, "paper_bgcolor": "#fffaf0", "plot_bgcolor": "#fffaf0", "showlegend": true, "title": "Monthly Data Jobs by Job Profile", "titlefont": {"color": "#655643", "family": "Merryweather", "size": 18}, "xaxis": {"fixedrange": true, "hoverformat": "Week %W, %Y", "tickmode": "auto", "ticks": "outside", "type": "date", "zerolinecolor": "#655643"}, "yaxis": {"fixedrange": true, "gridcolor": "#f2e6ce", "ticks": "outside", "tickwidth": 1, "title": "Number of submissions"}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("c2dc8648-cd16-4e8d-b42d-13728d01b244"));});</ ...

# %%
# Uncomment the line below to export an HTML version of the chart.
plotly.offline.plot(fig, filename = 'data_offer_profiles_stacked_bar.html', show_link=False)
# Out:
# 'file:///games/WORKSPACE/jpynb_Job_Market_Trends_Bulgaria/workbooks/data_offer_profiles_stacked_bar.html'

# %%
from IPython.core.display import HTML
with open('../resources/styles/datum.css', 'r') as f:
    style = f.read()
HTML(style)
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Fira+Mono|Fira+Sans|Fira+Sans+Condensed|Fira+Sans+Extra+Condensed');
# @import url('https://fonts.googleapis.com/css?family=Merriweather|Merriweather+Sans');
#
# .nbviewer {
#     background-color: #E5E1D8;
# }
#
# #notebook {
#     background-color: #E5E1D8;
# }
#
# #notebook-container {
#     background-color: #FFFAF0;
#     max-width: 1100px;
#     padding: 50px;
#     border-radius: 4px;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     -moz-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
# }
#
# /* Jupyter Notebook Header Styling */
# body > #header {
#     background-color:#fafafa;
# }
#
# #header #menubar #menus {
#     background-color:#fefefe;
# }
#
# /* Headings */
# .text_cell_render h1 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 900;
#     text-align: center;
#     font-size: 2.5em;
#     padding: 40px 0 12px 0;
#     text-shadow: 0 2px #FFFAF0, 0 3px #8c8b8b;
# }
#
# .text_cell_render h2 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 600;
#     font-size: 2.2em;
#     text-indent: 22px;
#     padding: 40px 0 6px 0;
#     margin-bottom: 24px;
#     border-bottom: 1px solid #655B4F;
# }
#
# .text_cell_render h3 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 300;
#     padding: 6px 0 0 0;
#     font-size: 1.6em;
# }
#
# .text_cell_render h4 {
#     color: #655B4F;
#     font-family: 'Merriweather', serif;
#     font-weight: 100;
#     font-size: 1.2em;
# }
#
# /* Use for subtitles and other non-headings */
# div.rendered_html > h5 {
#     font-family: 'Merriweather', serif;
#     line-height: 1.5em;
#     color: #655B4F;
#     font-weight: 200;
#     font-style: normal important!;
#     text-indent: 22px;
#     text-align: center;
#     margin-top: 0.5em;
#     padding: 6px 0 6px 0;
#     border-bottom: 1px solid #655B4F;
#     border-top: 1px solid #655B4F;
# }
#
# /* Use for image and chart captions */
# div.rendered_html > h6 {
#     font-family: 'Merriweather Sans', sans-serif;
#     font-size: 0.9em;
#     line-height: 1.5em;
#     color: #cac8c9;
#     font-weight: normal;
#     max-width: 525px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div#notebook-container p {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 1.2em;
#     line-height: 1.3em;
#     color: #655B4F;
# }
#
# /* Plotly Exported Charts Styling */
# .js-plotly-plot .plotly,
# .js-plotly-plot .plotly div {
#     direction: ltr;
#     font-family: "Fira Sans Extra Condensed", verdana, arial, sans-serif;
# }
#
# /* Lists */
# ol, ul {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     line-height: 1.3em;
#     color: #655B4F;
# }
#
# div.input_prompt {
#     color: #aad0bc;
#     font-size: 0.7em;
# }
#
# div.output_prompt {
#     color: #aad0bc;
#     font-size: 0.7em;
# }
#
# div.prompt {
#     min-width: 2ex;
# }
#
# div.output_subarea {
#     min-width: 425px;
#     max-width: calc(100% - 1ex);
#     padding: 0;
# }
#
# div.text_cell code {
#     padding: 2px;
#     background-color: #E5E1D8;
#     color: #483F3A;
#     font-family: 'Fira Mono', monospace;
#     font-size: 0.9em;
# }
#
# div.input_area {
#     background-color: #FFFAF0;
#     border: 1px solid #E5E1D8;
#     background: repeating-linear-gradient(135deg, #FFFAF0, #FFFAF0 5px, #F7F7ED 5px, #F7F7ED 10px);
# }
#
# div.cell.rendered.selected {
#     background: #F7F7ED;
#     border: 1px solid #293C34;
# }
#
# div.output_area img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.rendered_html pre, code {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 16px;
#     font-weight: 400;
#     color: #40362F;
#     background-color: #E5E1D8;
# }
#
# div.output_text pre {
#     font-family: 'Fira Sans Condensed', sans-serif;
#     font-size: 13px;
#     font-weight: 300;
#     color: #40362F;
# }
#
#
# pre, textarea {
#     overflow: hidden;
# }
#
# div.text_cell_render img {
#     max-height: 550px;
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# div.output output_scroll {
#     overflow-x: auto;
#     overflow-y: scroll;
#     max-height: 2000px;
# }
#
# div.rendered_html hr {
#     border: 0;
#     height: 1px;
#     background-color: #655B4F;
# }
#
# div.rendered_html pre, code {
#     color: #40362F;
#     background-color: #FFFAF0;
# }
#
# /* Links */
# a.link--embedview {
#     display: none;
# }
#
# a:link {
#     color: #293C34;
# }
#
# a:visited {
#     color: #293C34;
# }
#
# a:hover {
#     color: #557C6C;
# }
#
# a:focus {
#     color:#557C6C;
# }
#
# a:active {
#     font-weight: bold;
#     color:#80BCA3;
# }
#
# .rendered_html :link {
#     text-decoration: underline;
# }
#
# /* Colors for code highlighting */
# .CodeMirror pre {
#     font-family: 'Fira Mono', monospace;
#     font-size: 0.9em;
#     font-weight: 600;
#     letter-spacing: -2px;
# }
#
# .CodeMirror-code span.cm-keyword,
# .highlight .k,
# .highlight .ow {
#     color: #5F362E;
# }
#
# .CodeMirror-code span.cm-variable,
# .highlight .na {
#     color: #655B4F;
# }
#
# .CodeMirror-code span.cm-property {
#     color: #655B4F;
# }
#
# .CodeMirror-code span.cm-def {
#     color: #293C34;
# }
#
# .CodeMirror-code span.cm-operator {
#     color: #655B4F;
# }
#
# .CodeMirror-code span.cm-string,
# .highlight .s {
#     color: #0B7761;
# }
#
# .CodeMirror-code span.cm-number,
# .highlight .mb, .highlight .mf, .highlight .mh, .highlight .mi, .highlight .mo {
#     color: #265BCA;
# }
#
# .CodeMirror-code span.cm-comment,
# .highlight .c1, .highlight .cs {
#     color: #75AC95;
# }
#
# .CodeMirror-code span.cm-builtin,
# .highlight .nb {
#     color: #5F362E;
# }
#
# /* Code with no class applied (brackets mostly) */
# .CodeMirror-line > span {
#     color: #72614B;
# }
#
# /* Table styles */
# table {
#     border: 1px solid #BF4D28;
# }
#
#
# .rendered_html table th {
#     color: #40362F;
#     text-align: left;
#     background-color: #f2e6ce;
# }
#
# .rendered_html td {
#     color: #40362F;
#     text-align: left;
# }
#
# .rendered_html table tr:nth-child(odd) {
#     background-color: #F7F7ED;
# }
#
# .rendered_html table tr:nth-child(even) {
#     background-color: #FFFAF0;
# }
#
# iframe {
#     border-width: 0;
# }
#
# @media only screen and (max-width: 600px) {
#     #notebook-container {
#         background-color: #FFFAF0;
#         padding: 15px;
#         border-radius: 4px;
#         -webkit-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#         -moz-box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#         box-shadow: 0px 0px 12px 1px rgba(101,86,67,0.75);
#     }
#
#     .text_cell_render h1,
#     .text_cell_render h2 {
#         text-indent: 0;
#         text-align: left;
#         padding: 40px 22px 12px 22px;
#     }
# }
#
# </style>
